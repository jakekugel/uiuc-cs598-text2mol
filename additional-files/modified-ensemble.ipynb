# %% [markdown]
# This notebook contains the code that was used to perform the ablation study.  This is part of our project to reproduce the paper titled: "Text2Mol: Cross-Modal Molecule Retrieval with Natural Language Queries" by Carl Edwards, ChengXiang Zhai, and Heng Ji (see [1]).
#
# - Course: CS598 Deep Learning for Healthcare (Spring 2024)
# - Project Team:
#   1. Emily Meyer (emilynm4@illinois.edu)
#   2. Anna Wysocka (annamw2@illinois.edu)
#   3. Jake Kugel (jakugel2@illinois.edu)
#
#   Approximate runtime: 30 minutes (no GPU used)

# %%
# Record notebook start time
import time
start_time = time.time()

# %%
# CHANGE START
# This cell downloads data needed for this notebook, and stores it in the runtime's local folder, /content.
# It is safe to run this cell more than once, the download and unzip will be skipped after the initial run.
import gdown
import os

def download(id, zip_name, folder_name):
    """
    Downloads and unzips a zip file (must be shared as public) from Google Drive.
    If the zip was already downloaded, the download and unzip will be skipped.

    Parameters:
    id (str): The ID of the file to download.  This can be found in the URL of the file.
    zip_name (str): The name and path of the zip file to download.
    folder_name (str): The name of the folder to extract the zip file to. If the folder does not exist, it will be created.

    Returns:
    None
    """
    if os.path.exists(folder_name):
        print(f'The archive {zip_name} has already been downloaded and extracted to {folder_name}, skipping.')
    else:
        gdown.download(id=id, output=zip_name)
        # !unzip $zip_name -d $folder_name
        os.remove(zip_name)
        print('Download and unzip complete!')

download('1rezM24hhHwMoRWIushQ28po7PoYbw6Er', "/content/text2mol.zip", "/content/text2mol")
os.chdir('/content/text2mol')
# CHANGE END
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1rezM24hhHwMoRWIushQ28po7PoYbw6Er
# From (redirected): https://drive.google.com/uc?id=1rezM24hhHwMoRWIushQ28po7PoYbw6Er&confirm=t&uuid=e595734f-20ea-49a7-b829-51b0330dc045
# To: /content/text2mol.zip
# 100%|██████████| 1.87G/1.87G [00:19<00:00, 97.8MB/s]
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/text2mol/graph-data/raw/91858170.graph
#   inflating: /content/text2mol/graph-data/raw/91858171.graph
#   inflating: /content/text2mol/graph-data/raw/91858178.graph
#   inflating: /content/text2mol/graph-data/raw/91858184.graph
#   inflating: /content/text2mol/graph-data/raw/91858190.graph
#   inflating: /content/text2mol/graph-data/raw/91858192.graph
#   inflating: /content/text2mol/graph-data/raw/91858201.graph
#   inflating: /content/text2mol/graph-data/raw/91858205.graph
#   inflating: /content/text2mol/graph-data/raw/91858207.graph
#   inflating: /content/text2mol/graph-data/raw/91858209.graph
#   inflating: /content/text2mol/graph-data/raw/91858213.graph
#   inflating: /content/text2mol/graph-data/raw/91858217.graph
#   inflating: /content/text2mol/graph-data/raw/91858218.graph
#   inflating: /content/text2mol/graph-data/raw/91858220.graph
#   inflating: /content/text2mol/graph-data/raw/91858226.graph
#   inflating: /content/text2mol/graph-data/raw/91858227.graph
#   inflating: /content/text2mol/graph-data/raw/91858228.graph
#   inflating: /content/text2mol/graph-data/raw/91858229.graph
#   inflating: /content/text2mol/graph-data/raw/91858231.graph
#   inflating: /content/text2mol/graph-data/raw/91858235.graph
#   inflating: /content/text2mol/graph-data/raw/91858243.graph
#   inflating: /content/text2mol/graph-data/raw/91858249.graph
#   inflating: /content/text2mol/graph-data/raw/91858258.graph
#   inflating: /content/text2mol/graph-data/raw/91858262.graph
#   inflating: /content/text2mol/graph-data/raw/91858264.graph
#   inflating: /content/text2mol/graph-data/raw/91858265.graph
#   inflating: /content/text2mol/graph-data/raw/91858266.graph
#   inflating: /content/text2mol/graph-data/raw/91858268.graph
#   inflating: /content/text2mol/graph-data/raw/91858277.graph
#   inflating: /content/text2mol/graph-data/raw/91858279.graph
#   inflating: /content/text2mol/graph-data/raw/91858284.graph
#   inflating: /content/text2mol/graph-data/raw/91858286.graph
#   inflating: /content/text2mol/graph-data/raw/91858287.graph
#   inflating: /content/text2mol/graph-data/raw/91858288.graph
#   inflating: /content/text2mol/graph-data/raw/91858291.graph
#   inflating: /content/text2mol/graph-data/raw/91858295.graph
#   inflating: /content/text2mol/graph-data/raw/91858296.graph
#   inflating: /content/text2mol/graph-data/raw/91858297.graph
#   inflating: /content/text2mol/graph-data/raw/91858299.graph
#   inflating: /content/text2mol/graph-data/raw/91858300.graph
#   inflating: /content/text2mol/graph-data/raw/91858302.graph
#   inflating: /content/text2mol/graph-data/raw/91858306.graph
#   inflating: /content/text2mol/graph-data/raw/91858308.graph
#   inflating: /content/text2mol/graph-data/raw/91858310.graph
#   inflating: /content/text2mol/graph-data/raw/91858313.graph
#   inflating: /content/text2mol/graph-data/raw/91858314.graph
#   inflating: /content/text2mol/graph-data/raw/91858315.graph
#   inflating: /content/text2mol/graph-data/raw/91858319.graph
#   inflating: /content/text2mol/graph-data/raw/91858320.graph
#   inflating: /content/text2mol/graph-data/raw/91858323.graph
#   inflating: /content/text2mol/graph-data/raw/91858324.graph
#   inflating: /content/text2mol/graph-data/raw/91858329.graph
#   inflating: /content/text2mol/graph-data/raw/91858331.graph
#   inflating: /content/text2mol/graph-data/raw/91858336.graph
#   inflating: /content/text2mol/graph-data/raw/91858338.graph
#   inflating: /content/text2mol/graph-data/raw/91858344.graph
#   inflating: /content/text2mol/graph-data/raw/91858349.graph
#   inflating: /content/text2mol/graph-data/raw/91858350.graph
#   inflating: /content/text2mol/graph-data/raw/91858353.graph
#   inflating: /content/text2mol/graph-data/raw/91858361.graph
#   inflating: /content/text2mol/graph-data/raw/91858363.graph
#   inflating: /content/text2mol/graph-data/raw/91858364.graph
#   inflating: /content/text2mol/graph-data/raw/91858365.graph
#   inflating: /content/text2mol/graph-data/raw/91858367.graph
#   inflating: /content/text2mol/graph-data/raw/91858368.graph
#   inflating: /content/text2mol/graph-data/raw/91858371.graph
#   inflating: /content/text2mol/graph-data/raw/91858372.graph
#   inflating: /content/text2mol/graph-data/raw/91858375.graph
#   inflating: /content/text2mol/graph-data/raw/91858377.graph
#   inflating: /content/text2mol/graph-data/raw/91858379.graph
#   inflating: /content/text2mol/graph-data/raw/91858384.graph
#   inflating: /content/text2mol/graph-data/raw/91858385.graph
#   inflating: /content/text2mol/graph-data/raw/91858386.graph
#   inflating: /content/text2mol/graph-data/raw/91858387.graph
#   inflating: /content/text2mol/graph-data/raw/91858390.graph
#   inflating: /content/text2mol/graph-data/raw/91858391.graph
#   inflating: /content/text2mol/graph-data/raw/91858393.graph
#   inflating: /content/text2mol/graph-data/raw/91858394.graph
#   inflating: /content/text2mol/graph-data/raw/91858398.graph
#   inflating: /content/text2mol/graph-data/raw/91858399.graph
#   inflating: /content/text2mol/graph-data/raw/91858400.graph
#   inflating: /content/text2mol/graph-data/raw/91858407.graph
#   inflating: /content/text2mol/graph-data/raw/91858410.graph
#   inflating: /content/text2mol/graph-data/raw/91858412.graph
#   inflating: /content/text2mol/graph-data/raw/91858414.graph
#   inflating: /content/text2mol/graph-data/raw/91858415.graph
#   inflating: /content/text2mol/graph-data/raw/91858416.graph
#   inflating: /content/text2mol/graph-data/raw/91858417.graph
#   inflating: /content/text2mol/graph-data/raw/91858420.graph
#   inflating: /content/text2mol/graph-data/raw/91858424.graph
#   inflating: /content/text2mol/graph-data/raw/91858426.graph
#   inflating: /content/text2mol/graph-data/raw/91858428.graph
#   inflating: /content/text2mol/graph-data/raw/91858432.graph
#   inflating: /content/text2mol/graph-data/raw/91858436.graph
#   inflating: /content/text2mol/graph-data/raw/91858440.graph
#   inflating: /content/text2mol/graph-data/raw/91858441.graph
#   inflating: /content/text2mol/graph-data/raw/91858442.graph
#   inflating: /content/text2mol/graph-data/raw/91858447.graph
#   inflating: /content/text2mol/graph-data/raw/91858448.graph
#   inflating: /content/text2mol/graph-data/raw/91858449.graph
#   inflating: /content/text2mol/graph-data/raw/91858450.graph
#   inflating: /content/text2mol/graph-data/raw/91858452.graph
#   inflating: /content/text2mol/graph-data/raw/91858454.graph
#   inflating: /content/text2mol/graph-data/raw/91858457.graph
#   inflating: /content/text2mol/graph-data/raw/91858459.graph
#   inflating: /content/text2mol/graph-data/raw/91858461.graph
#   inflating: /content/text2mol/graph-data/raw/91858462.graph
#   inflating: /content/text2mol/graph-data/raw/91858463.graph
#   inflating: /content/text2mol/graph-data/raw/91858464.graph
#   inflating: /content/text2mol/graph-data/raw/91858469.graph
#   inflating: /content/text2mol/graph-data/raw/91858471.graph
#   inflating: /content/text2mol/graph-data/raw/91858472.graph
#   inflating: /content/text2mol/graph-data/raw/91858475.graph
#   inflating: /content/text2mol/graph-data/raw/91858488.graph
#   inflating: /content/text2mol/graph-data/raw/91858489.graph
#   inflating: /content/text2mol/graph-data/raw/91858491.graph
#   inflating: /content/text2mol/graph-data/raw/91858492.graph
#   inflating: /content/text2mol/graph-data/raw/91858494.graph
#   inflating: /content/text2mol/graph-data/raw/91858495.graph
#   inflating: /content/text2mol/graph-data/raw/91858497.graph
#   inflating: /content/text2mol/graph-data/raw/91858500.graph
#   inflating: /content/text2mol/graph-data/raw/91858503.graph
#   inflating: /content/text2mol/graph-data/raw/91858505.graph
#   inflating: /content/text2mol/graph-data/raw/91858507.graph
#   inflating: /content/text2mol/graph-data/raw/91858509.graph
#   inflating: /content/text2mol/graph-data/raw/91858510.graph
#   inflating: /content/text2mol/graph-data/raw/91858515.graph
#   inflating: /content/text2mol/graph-data/raw/91858516.graph
#   inflating: /content/text2mol/graph-data/raw/91858518.graph
#   inflating: /content/text2mol/graph-data/raw/91858521.graph
#   inflating: /content/text2mol/graph-data/raw/91858522.graph
#   inflating: /content/text2mol/graph-data/raw/91858524.graph
#   inflating: /content/text2mol/graph-data/raw/91858525.graph
#   inflating: /content/text2mol/graph-data/raw/91858528.graph
#   inflating: /content/text2mol/graph-data/raw/91858529.graph
#   inflating: /content/text2mol/graph-data/raw/91858530.graph
#   inflating: /content/text2mol/graph-data/raw/91858536.graph
#   inflating: /content/text2mol/graph-data/raw/91858540.graph
#   inflating: /content/text2mol/graph-data/raw/91858542.graph
#   inflating: /content/text2mol/graph-data/raw/91858543.graph
#   inflating: /content/text2mol/graph-data/raw/91858544.graph
#   inflating: /content/text2mol/graph-data/raw/91858546.graph
#   inflating: /content/text2mol/graph-data/raw/91858548.graph
#   inflating: /content/text2mol/graph-data/raw/91858550.graph
#   inflating: /content/text2mol/graph-data/raw/91858551.graph
#   inflating: /content/text2mol/graph-data/raw/91858552.graph
#   inflating: /content/text2mol/graph-data/raw/91858555.graph
#   inflating: /content/text2mol/graph-data/raw/91858556.graph
#   inflating: /content/text2mol/graph-data/raw/91858558.graph
#   inflating: /content/text2mol/graph-data/raw/91858562.graph
#   inflating: /content/text2mol/graph-data/raw/91858563.graph
#   inflating: /content/text2mol/graph-data/raw/91858566.graph
#   inflating: /content/text2mol/graph-data/raw/91858568.graph
#   inflating: /content/text2mol/graph-data/raw/91858571.graph
#   inflating: /content/text2mol/graph-data/raw/91858573.graph
#   inflating: /content/text2mol/graph-data/raw/91858574.graph
#   inflating: /content/text2mol/graph-data/raw/91858575.graph
#   inflating: /content/text2mol/graph-data/raw/91858581.graph
#   inflating: /content/text2mol/graph-data/raw/91858584.graph
#   inflating: /content/text2mol/graph-data/raw/91858586.graph
#   inflating: /content/text2mol/graph-data/raw/91858587.graph
#   inflating: /content/text2mol/graph-data/raw/91858588.graph
#   inflating: /content/text2mol/graph-data/raw/91858600.graph
#   inflating: /content/text2mol/graph-data/raw/91858605.graph
#   inflating: /content/text2mol/graph-data/raw/91858606.graph
#   inflating: /content/text2mol/graph-data/raw/91858611.graph
#   inflating: /content/text2mol/graph-data/raw/91858612.graph
#   inflating: /content/text2mol/graph-data/raw/91858614.graph
#   inflating: /content/text2mol/graph-data/raw/91858615.graph
#   inflating: /content/text2mol/graph-data/raw/91858617.graph
#   inflating: /content/text2mol/graph-data/raw/91858621.graph
#   inflating: /content/text2mol/graph-data/raw/91858623.graph
#   inflating: /content/text2mol/graph-data/raw/91858627.graph
#   inflating: /content/text2mol/graph-data/raw/91858629.graph
#   inflating: /content/text2mol/graph-data/raw/91858631.graph
#   inflating: /content/text2mol/graph-data/raw/91858632.graph
#   inflating: /content/text2mol/graph-data/raw/91858633.graph
#   inflating: /content/text2mol/graph-data/raw/91858635.graph
#   inflating: /content/text2mol/graph-data/raw/91858636.graph
#   inflating: /content/text2mol/graph-data/raw/91858639.graph
#   inflating: /content/text2mol/graph-data/raw/91858643.graph
#   inflating: /content/text2mol/graph-data/raw/91858644.graph
#   inflating: /content/text2mol/graph-data/raw/91858654.graph
#   inflating: /content/text2mol/graph-data/raw/91858655.graph
#   inflating: /content/text2mol/graph-data/raw/91858663.graph
#   inflating: /content/text2mol/graph-data/raw/91858666.graph
#   inflating: /content/text2mol/graph-data/raw/91858667.graph
#   inflating: /content/text2mol/graph-data/raw/91858671.graph
#   inflating: /content/text2mol/graph-data/raw/91858673.graph
#   inflating: /content/text2mol/graph-data/raw/91858675.graph
#   inflating: /content/text2mol/graph-data/raw/91858676.graph
#   inflating: /content/text2mol/graph-data/raw/91858679.graph
#   inflating: /content/text2mol/graph-data/raw/91858680.graph
#   inflating: /content/text2mol/graph-data/raw/91858683.graph
#   inflating: /content/text2mol/graph-data/raw/91858685.graph
#   inflating: /content/text2mol/graph-data/raw/91858688.graph
#   inflating: /content/text2mol/graph-data/raw/91858690.graph
#   inflating: /content/text2mol/graph-data/raw/91858694.graph
#   inflating: /content/text2mol/graph-data/raw/91858697.graph
#   inflating: /content/text2mol/graph-data/raw/91858700.graph
#   inflating: /content/text2mol/graph-data/raw/91858702.graph
#   inflating: /content/text2mol/graph-data/raw/91858705.graph
#   inflating: /content/text2mol/graph-data/raw/91858709.graph
#   inflating: /content/text2mol/graph-data/raw/91858711.graph
#   inflating: /content/text2mol/graph-data/raw/91858713.graph
#   inflating: /content/text2mol/graph-data/raw/91858715.graph
#   inflating: /content/text2mol/graph-data/raw/91858716.graph
#   inflating: /content/text2mol/graph-data/raw/91858720.graph
#   inflating: /content/text2mol/graph-data/raw/91858725.graph
#   inflating: /content/text2mol/graph-data/raw/91858730.graph
#   inflating: /content/text2mol/graph-data/raw/91858731.graph
#   inflating: /content/text2mol/graph-data/raw/91858733.graph
#   inflating: /content/text2mol/graph-data/raw/91858738.graph
#   inflating: /content/text2mol/graph-data/raw/91858742.graph
#   inflating: /content/text2mol/graph-data/raw/91858745.graph
#   inflating: /content/text2mol/graph-data/raw/91858749.graph
#   inflating: /content/text2mol/graph-data/raw/91858751.graph
#   inflating: /content/text2mol/graph-data/raw/91858754.graph
#   inflating: /content/text2mol/graph-data/raw/91858756.graph
#   inflating: /content/text2mol/graph-data/raw/91858758.graph
#   inflating: /content/text2mol/graph-data/raw/91858760.graph
#   inflating: /content/text2mol/graph-data/raw/91858762.graph
#   inflating: /content/text2mol/graph-data/raw/91858764.graph
#   inflating: /content/text2mol/graph-data/raw/91858766.graph
#   inflating: /content/text2mol/graph-data/raw/91858769.graph
#   inflating: /content/text2mol/graph-data/raw/91858771.graph
#   inflating: /content/text2mol/graph-data/raw/91858772.graph
#   inflating: /content/text2mol/graph-data/raw/91858773.graph
#   inflating: /content/text2mol/graph-data/raw/91858777.graph
#   inflating: /content/text2mol/graph-data/raw/91858778.graph
#   inflating: /content/text2mol/graph-data/raw/91858780.graph
#   inflating: /content/text2mol/graph-data/raw/91858781.graph
#   inflating: /content/text2mol/graph-data/raw/91858782.graph
#   inflating: /content/text2mol/graph-data/raw/91858786.graph
#   inflating: /content/text2mol/graph-data/raw/91858787.graph
#   inflating: /content/text2mol/graph-data/raw/91858788.graph
#   inflating: /content/text2mol/graph-data/raw/91858793.graph
#   inflating: /content/text2mol/graph-data/raw/91858794.graph
#   inflating: /content/text2mol/graph-data/raw/91858801.graph
#   inflating: /content/text2mol/graph-data/raw/91858812.graph
#   inflating: /content/text2mol/graph-data/raw/91858816.graph
#   inflating: /content/text2mol/graph-data/raw/91858817.graph
#   inflating: /content/text2mol/graph-data/raw/91858821.graph
#   inflating: /content/text2mol/graph-data/raw/91858825.graph
#   inflating: /content/text2mol/graph-data/raw/91858832.graph
#   inflating: /content/text2mol/graph-data/raw/91858837.graph
#   inflating: /content/text2mol/graph-data/raw/91858838.graph
#   inflating: /content/text2mol/graph-data/raw/91858840.graph
#   inflating: /content/text2mol/graph-data/raw/91858841.graph
#   inflating: /content/text2mol/graph-data/raw/91858845.graph
#   inflating: /content/text2mol/graph-data/raw/91858846.graph
#   inflating: /content/text2mol/graph-data/raw/91858848.graph
#   inflating: /content/text2mol/graph-data/raw/91858853.graph
#   inflating: /content/text2mol/graph-data/raw/91858855.graph
#   inflating: /content/text2mol/graph-data/raw/91858862.graph
#   inflating: /content/text2mol/graph-data/raw/91858873.graph
#   inflating: /content/text2mol/graph-data/raw/91858874.graph
#   inflating: /content/text2mol/graph-data/raw/91858878.graph
#   inflating: /content/text2mol/graph-data/raw/91858880.graph
#   inflating: /content/text2mol/graph-data/raw/91858885.graph
#   inflating: /content/text2mol/graph-data/raw/91858886.graph
#   inflating: /content/text2mol/graph-data/raw/91858887.graph
#   inflating: /content/text2mol/graph-data/raw/91858891.graph
#   inflating: /content/text2mol/graph-data/raw/91858892.graph
#   inflating: /content/text2mol/graph-data/raw/91858896.graph
#   inflating: /content/text2mol/graph-data/raw/91858897.graph
#   inflating: /content/text2mol/graph-data/raw/91858899.graph
#   inflating: /content/text2mol/graph-data/raw/91858900.graph
#   inflating: /content/text2mol/graph-data/raw/91858902.graph
#   inflating: /content/text2mol/graph-data/raw/91858912.graph
#   inflating: /content/text2mol/graph-data/raw/91858916.graph
#   inflating: /content/text2mol/graph-data/raw/91858918.graph
#   inflating: /content/text2mol/graph-data/raw/91858919.graph
#   inflating: /content/text2mol/graph-data/raw/91858921.graph
#   inflating: /content/text2mol/graph-data/raw/91858926.graph
#   inflating: /content/text2mol/graph-data/raw/91858927.graph
#   inflating: /content/text2mol/graph-data/raw/91858930.graph
#   inflating: /content/text2mol/graph-data/raw/91858940.graph
#   inflating: /content/text2mol/graph-data/raw/91858942.graph
#   inflating: /content/text2mol/graph-data/raw/91858947.graph
#   inflating: /content/text2mol/graph-data/raw/91858948.graph
#   inflating: /content/text2mol/graph-data/raw/91858952.graph
#   inflating: /content/text2mol/graph-data/raw/91858953.graph
#   inflating: /content/text2mol/graph-data/raw/91858954.graph
#   inflating: /content/text2mol/graph-data/raw/91858955.graph
#   inflating: /content/text2mol/graph-data/raw/91858956.graph
#   inflating: /content/text2mol/graph-data/raw/91858957.graph
#   inflating: /content/text2mol/graph-data/raw/91858959.graph
#   inflating: /content/text2mol/graph-data/raw/91858961.graph
#   inflating: /content/text2mol/graph-data/raw/91858962.graph
#   inflating: /content/text2mol/graph-data/raw/91858964.graph
#   inflating: /content/text2mol/graph-data/raw/91858965.graph
#   inflating: /content/text2mol/graph-data/raw/91858966.graph
#   inflating: /content/text2mol/graph-data/raw/91858968.graph
#   inflating: /content/text2mol/graph-data/raw/91858969.graph
#   inflating: /content/text2mol/graph-data/raw/91858970.graph
#   inflating: /content/text2mol/graph-data/raw/91858974.graph
#   inflating: /content/text2mol/graph-data/raw/91858979.graph
#   inflating: /content/text2mol/graph-data/raw/91858980.graph
#   inflating: /content/text2mol/graph-data/raw/91858982.graph
#   inflating: /content/text2mol/graph-data/raw/91858984.graph
#   inflating: /content/text2mol/graph-data/raw/91858985.graph
#   inflating: /content/text2mol/graph-data/raw/91858990.graph
#   inflating: /content/text2mol/graph-data/raw/91858991.graph
#   inflating: /content/text2mol/graph-data/raw/91858993.graph
#   inflating: /content/text2mol/graph-data/raw/91858994.graph
#   inflating: /content/text2mol/graph-data/raw/91858997.graph
#   inflating: /content/text2mol/graph-data/raw/91858998.graph
#   inflating: /content/text2mol/graph-data/raw/91859004.graph
#   inflating: /content/text2mol/graph-data/raw/91859006.graph
#   inflating: /content/text2mol/graph-data/raw/91859011.graph
#   inflating: /content/text2mol/graph-data/raw/91859012.graph
#   inflating: /content/text2mol/graph-data/raw/91859015.graph
#   inflating: /content/text2mol/graph-data/raw/91859017.graph
#   inflating: /content/text2mol/graph-data/raw/91859018.graph
#   inflating: /content/text2mol/graph-data/raw/91859020.graph
#   inflating: /content/text2mol/graph-data/raw/91859022.graph
#   inflating: /content/text2mol/graph-data/raw/91859024.graph
#   inflating: /content/text2mol/graph-data/raw/91859029.graph
#   inflating: /content/text2mol/graph-data/raw/91859030.graph
#   inflating: /content/text2mol/graph-data/raw/91859034.graph
#   inflating: /content/text2mol/graph-data/raw/91859035.graph
#   inflating: /content/text2mol/graph-data/raw/91859038.graph
#   inflating: /content/text2mol/graph-data/raw/91859040.graph
#   inflating: /content/text2mol/graph-data/raw/91859043.graph
#   inflating: /content/text2mol/graph-data/raw/91859046.graph
#   inflating: /content/text2mol/graph-data/raw/91859050.graph
#   inflating: /content/text2mol/graph-data/raw/91859053.graph
#   inflating: /content/text2mol/graph-data/raw/91859060.graph
#   inflating: /content/text2mol/graph-data/raw/91859070.graph
#   inflating: /content/text2mol/graph-data/raw/91859076.graph
#   inflating: /content/text2mol/graph-data/raw/91859077.graph
#   inflating: /content/text2mol/graph-data/raw/91859078.graph
#   inflating: /content/text2mol/graph-data/raw/91859081.graph
#   inflating: /content/text2mol/graph-data/raw/91859085.graph
#   inflating: /content/text2mol/graph-data/raw/91859086.graph
#   inflating: /content/text2mol/graph-data/raw/91859095.graph
#   inflating: /content/text2mol/graph-data/raw/91859096.graph
#   inflating: /content/text2mol/graph-data/raw/91859097.graph
#   inflating: /content/text2mol/graph-data/raw/91859101.graph
#   inflating: /content/text2mol/graph-data/raw/91859102.graph
#   inflating: /content/text2mol/graph-data/raw/91859104.graph
#   inflating: /content/text2mol/graph-data/raw/91859117.graph
#   inflating: /content/text2mol/graph-data/raw/91859121.graph
#   inflating: /content/text2mol/graph-data/raw/91859124.graph
#   inflating: /content/text2mol/graph-data/raw/91859129.graph
#   inflating: /content/text2mol/graph-data/raw/91859133.graph
#   inflating: /content/text2mol/graph-data/raw/91859137.graph
#   inflating: /content/text2mol/graph-data/raw/91859143.graph
#   inflating: /content/text2mol/graph-data/raw/91859146.graph
#   inflating: /content/text2mol/graph-data/raw/91859150.graph
#   inflating: /content/text2mol/graph-data/raw/91859152.graph
#   inflating: /content/text2mol/graph-data/raw/91859155.graph
#   inflating: /content/text2mol/graph-data/raw/91859156.graph
#   inflating: /content/text2mol/graph-data/raw/91859157.graph
#   inflating: /content/text2mol/graph-data/raw/91859158.graph
#   inflating: /content/text2mol/graph-data/raw/91859163.graph
#   inflating: /content/text2mol/graph-data/raw/91859164.graph
#   inflating: /content/text2mol/graph-data/raw/91859166.graph
#   inflating: /content/text2mol/graph-data/raw/91859168.graph
#   inflating: /content/text2mol/graph-data/raw/91859169.graph
#   inflating: /content/text2mol/graph-data/raw/91859171.graph
#   inflating: /content/text2mol/graph-data/raw/91859176.graph
#   inflating: /content/text2mol/graph-data/raw/91859178.graph
#   inflating: /content/text2mol/graph-data/raw/91859179.graph
#   inflating: /content/text2mol/graph-data/raw/91859181.graph
#   inflating: /content/text2mol/graph-data/raw/91859187.graph
#   inflating: /content/text2mol/graph-data/raw/91859192.graph
#   inflating: /content/text2mol/graph-data/raw/91859194.graph
#   inflating: /content/text2mol/graph-data/raw/91859197.graph
#   inflating: /content/text2mol/graph-data/raw/91859203.graph
#   inflating: /content/text2mol/graph-data/raw/91859209.graph
#   inflating: /content/text2mol/graph-data/raw/91859215.graph
#   inflating: /content/text2mol/graph-data/raw/91859220.graph
#   inflating: /content/text2mol/graph-data/raw/91859226.graph
#   inflating: /content/text2mol/graph-data/raw/91859234.graph
#   inflating: /content/text2mol/graph-data/raw/91859235.graph
#   inflating: /content/text2mol/graph-data/raw/91859242.graph
#   inflating: /content/text2mol/graph-data/raw/91859249.graph
#   inflating: /content/text2mol/graph-data/raw/91859250.graph
#   inflating: /content/text2mol/graph-data/raw/91859255.graph
#   inflating: /content/text2mol/graph-data/raw/91859256.graph
#   inflating: /content/text2mol/graph-data/raw/91859257.graph
#   inflating: /content/text2mol/graph-data/raw/91859258.graph
#   inflating: /content/text2mol/graph-data/raw/91859259.graph
#   inflating: /content/text2mol/graph-data/raw/91859260.graph
#   inflating: /content/text2mol/graph-data/raw/91859261.graph
#   inflating: /content/text2mol/graph-data/raw/91859262.graph
#   inflating: /content/text2mol/graph-data/raw/91859264.graph
#   inflating: /content/text2mol/graph-data/raw/91859271.graph
#   inflating: /content/text2mol/graph-data/raw/91859272.graph
#   inflating: /content/text2mol/graph-data/raw/91859273.graph
#   inflating: /content/text2mol/graph-data/raw/91859276.graph
#   inflating: /content/text2mol/graph-data/raw/91859278.graph
#   inflating: /content/text2mol/graph-data/raw/91859280.graph
#   inflating: /content/text2mol/graph-data/raw/91859282.graph
#   inflating: /content/text2mol/graph-data/raw/91859286.graph
#   inflating: /content/text2mol/graph-data/raw/91859289.graph
#   inflating: /content/text2mol/graph-data/raw/91859292.graph
#   inflating: /content/text2mol/graph-data/raw/91859298.graph
#   inflating: /content/text2mol/graph-data/raw/91859299.graph
#   inflating: /content/text2mol/graph-data/raw/91859300.graph
#   inflating: /content/text2mol/graph-data/raw/91859303.graph
#   inflating: /content/text2mol/graph-data/raw/91859306.graph
#   inflating: /content/text2mol/graph-data/raw/91859307.graph
#   inflating: /content/text2mol/graph-data/raw/91859310.graph
#   inflating: /content/text2mol/graph-data/raw/91859315.graph
#   inflating: /content/text2mol/graph-data/raw/91859316.graph
#   inflating: /content/text2mol/graph-data/raw/91859317.graph
#   inflating: /content/text2mol/graph-data/raw/91859322.graph
#   inflating: /content/text2mol/graph-data/raw/91859323.graph
#   inflating: /content/text2mol/graph-data/raw/91859324.graph
#   inflating: /content/text2mol/graph-data/raw/91859329.graph
#   inflating: /content/text2mol/graph-data/raw/91859330.graph
#   inflating: /content/text2mol/graph-data/raw/91859334.graph
#   inflating: /content/text2mol/graph-data/raw/91859336.graph
#   inflating: /content/text2mol/graph-data/raw/91859337.graph
#   inflating: /content/text2mol/graph-data/raw/91859343.graph
#   inflating: /content/text2mol/graph-data/raw/91859345.graph
#   inflating: /content/text2mol/graph-data/raw/91859346.graph
#   inflating: /content/text2mol/graph-data/raw/91859353.graph
#   inflating: /content/text2mol/graph-data/raw/91859354.graph
#   inflating: /content/text2mol/graph-data/raw/91859362.graph
#   inflating: /content/text2mol/graph-data/raw/91859365.graph
#   inflating: /content/text2mol/graph-data/raw/91859366.graph
#   inflating: /content/text2mol/graph-data/raw/91859372.graph
#   inflating: /content/text2mol/graph-data/raw/91859373.graph
#   inflating: /content/text2mol/graph-data/raw/91859378.graph
#   inflating: /content/text2mol/graph-data/raw/91859380.graph
#   inflating: /content/text2mol/graph-data/raw/91859382.graph
#   inflating: /content/text2mol/graph-data/raw/91859383.graph
#   inflating: /content/text2mol/graph-data/raw/91859385.graph
#   inflating: /content/text2mol/graph-data/raw/91859387.graph
#   inflating: /content/text2mol/graph-data/raw/91859388.graph
#   inflating: /content/text2mol/graph-data/raw/91859392.graph
#   inflating: /content/text2mol/graph-data/raw/91859395.graph
#   inflating: /content/text2mol/graph-data/raw/91859396.graph
#   inflating: /content/text2mol/graph-data/raw/91859397.graph
#   inflating: /content/text2mol/graph-data/raw/91859399.graph
#   inflating: /content/text2mol/graph-data/raw/91859401.graph
#   inflating: /content/text2mol/graph-data/raw/91859403.graph
#   inflating: /content/text2mol/graph-data/raw/91859405.graph
#   inflating: /content/text2mol/graph-data/raw/91859408.graph
#   inflating: /content/text2mol/graph-data/raw/91859411.graph
#   inflating: /content/text2mol/graph-data/raw/91859412.graph
#   inflating: /content/text2mol/graph-data/raw/91859414.graph
#   inflating: /content/text2mol/graph-data/raw/91859415.graph
#   inflating: /content/text2mol/graph-data/raw/91859417.graph
#   inflating: /content/text2mol/graph-data/raw/91859418.graph
#   inflating: /content/text2mol/graph-data/raw/91859419.graph
#   inflating: /content/text2mol/graph-data/raw/91859423.graph
#   inflating: /content/text2mol/graph-data/raw/91859424.graph
#   inflating: /content/text2mol/graph-data/raw/91859427.graph
#   inflating: /content/text2mol/graph-data/raw/91859428.graph
#   inflating: /content/text2mol/graph-data/raw/91859431.graph
#   inflating: /content/text2mol/graph-data/raw/91859432.graph
#   inflating: /content/text2mol/graph-data/raw/91859436.graph
#   inflating: /content/text2mol/graph-data/raw/91859438.graph
#   inflating: /content/text2mol/graph-data/raw/91859439.graph
#   inflating: /content/text2mol/graph-data/raw/91859440.graph
#   inflating: /content/text2mol/graph-data/raw/91859441.graph
#   inflating: /content/text2mol/graph-data/raw/91859444.graph
#   inflating: /content/text2mol/graph-data/raw/91859449.graph
#   inflating: /content/text2mol/graph-data/raw/91859450.graph
#   inflating: /content/text2mol/graph-data/raw/91859454.graph
#   inflating: /content/text2mol/graph-data/raw/91859456.graph
#   inflating: /content/text2mol/graph-data/raw/91859457.graph
#   inflating: /content/text2mol/graph-data/raw/91859458.graph
#   inflating: /content/text2mol/graph-data/raw/91859461.graph
#   inflating: /content/text2mol/graph-data/raw/91859463.graph
#   inflating: /content/text2mol/graph-data/raw/91859464.graph
#   inflating: /content/text2mol/graph-data/raw/91859470.graph
#   inflating: /content/text2mol/graph-data/raw/91859473.graph
#   inflating: /content/text2mol/graph-data/raw/91859482.graph
#   inflating: /content/text2mol/graph-data/raw/91859487.graph
#   inflating: /content/text2mol/graph-data/raw/91859490.graph
#   inflating: /content/text2mol/graph-data/raw/91859493.graph
#   inflating: /content/text2mol/graph-data/raw/91859497.graph
#   inflating: /content/text2mol/graph-data/raw/91859507.graph
#   inflating: /content/text2mol/graph-data/raw/91859508.graph
#   inflating: /content/text2mol/graph-data/raw/91859511.graph
#   inflating: /content/text2mol/graph-data/raw/91859514.graph
#   inflating: /content/text2mol/graph-data/raw/91859519.graph
#   inflating: /content/text2mol/graph-data/raw/91859523.graph
#   inflating: /content/text2mol/graph-data/raw/91859526.graph
#   inflating: /content/text2mol/graph-data/raw/91859527.graph
#   inflating: /content/text2mol/graph-data/raw/91859529.graph
#   inflating: /content/text2mol/graph-data/raw/91859530.graph
#   inflating: /content/text2mol/graph-data/raw/91859533.graph
#   inflating: /content/text2mol/graph-data/raw/91859555.graph
#   inflating: /content/text2mol/graph-data/raw/91859563.graph
#   inflating: /content/text2mol/graph-data/raw/91859564.graph
#   inflating: /content/text2mol/graph-data/raw/91859566.graph
#   inflating: /content/text2mol/graph-data/raw/91859567.graph
#   inflating: /content/text2mol/graph-data/raw/91859569.graph
#   inflating: /content/text2mol/graph-data/raw/91859573.graph
#   inflating: /content/text2mol/graph-data/raw/91859574.graph
#   inflating: /content/text2mol/graph-data/raw/91859575.graph
#   inflating: /content/text2mol/graph-data/raw/91859576.graph
#   inflating: /content/text2mol/graph-data/raw/91859580.graph
#   inflating: /content/text2mol/graph-data/raw/91859588.graph
#   inflating: /content/text2mol/graph-data/raw/91859589.graph
#   inflating: /content/text2mol/graph-data/raw/91859590.graph
#   inflating: /content/text2mol/graph-data/raw/91859593.graph
#   inflating: /content/text2mol/graph-data/raw/91859594.graph
#   inflating: /content/text2mol/graph-data/raw/91859600.graph
#   inflating: /content/text2mol/graph-data/raw/91859603.graph
#   inflating: /content/text2mol/graph-data/raw/91859606.graph
#   inflating: /content/text2mol/graph-data/raw/91859608.graph
#   inflating: /content/text2mol/graph-data/raw/91859615.graph
#   inflating: /content/text2mol/graph-data/raw/91859617.graph
#   inflating: /content/text2mol/graph-data/raw/91859618.graph
#   inflating: /content/text2mol/graph-data/raw/91859621.graph
#   inflating: /content/text2mol/graph-data/raw/91859622.graph
#   inflating: /content/text2mol/graph-data/raw/91859632.graph
#   inflating: /content/text2mol/graph-data/raw/91859635.graph
#   inflating: /content/text2mol/graph-data/raw/91859636.graph
#   inflating: /content/text2mol/graph-data/raw/91859637.graph
#   inflating: /content/text2mol/graph-data/raw/91859640.graph
#   inflating: /content/text2mol/graph-data/raw/91859643.graph
#   inflating: /content/text2mol/graph-data/raw/91859645.graph
#   inflating: /content/text2mol/graph-data/raw/91859651.graph
#   inflating: /content/text2mol/graph-data/raw/91859653.graph
#   inflating: /content/text2mol/graph-data/raw/91859656.graph
#   inflating: /content/text2mol/graph-data/raw/91859658.graph
#   inflating: /content/text2mol/graph-data/raw/91859660.graph
#   inflating: /content/text2mol/graph-data/raw/91859662.graph
#   inflating: /content/text2mol/graph-data/raw/91859666.graph
#   inflating: /content/text2mol/graph-data/raw/91859668.graph
#   inflating: /content/text2mol/graph-data/raw/91859675.graph
#   inflating: /content/text2mol/graph-data/raw/91859676.graph
#   inflating: /content/text2mol/graph-data/raw/91859677.graph
#   inflating: /content/text2mol/graph-data/raw/91859678.graph
#   inflating: /content/text2mol/graph-data/raw/91859679.graph
#   inflating: /content/text2mol/graph-data/raw/91859688.graph
#   inflating: /content/text2mol/graph-data/raw/91859690.graph
#   inflating: /content/text2mol/graph-data/raw/91859691.graph
#   inflating: /content/text2mol/graph-data/raw/91859702.graph
#   inflating: /content/text2mol/graph-data/raw/91859703.graph
#   inflating: /content/text2mol/graph-data/raw/91859718.graph
#   inflating: /content/text2mol/graph-data/raw/91859723.graph
#   inflating: /content/text2mol/graph-data/raw/91859724.graph
#   inflating: /content/text2mol/graph-data/raw/91859726.graph
#   inflating: /content/text2mol/graph-data/raw/91859727.graph
#   inflating: /content/text2mol/graph-data/raw/91859728.graph
#   inflating: /content/text2mol/graph-data/raw/91859733.graph
#   inflating: /content/text2mol/graph-data/raw/91859735.graph
#   inflating: /content/text2mol/graph-data/raw/91859736.graph
#   inflating: /content/text2mol/graph-data/raw/91859737.graph
#   inflating: /content/text2mol/graph-data/raw/91859740.graph
#   inflating: /content/text2mol/graph-data/raw/91859743.graph
#   inflating: /content/text2mol/graph-data/raw/91859744.graph
#   inflating: /content/text2mol/graph-data/raw/91859745.graph
#   inflating: /content/text2mol/graph-data/raw/91859751.graph
#   inflating: /content/text2mol/graph-data/raw/91859753.graph
#   inflating: /content/text2mol/graph-data/raw/91859757.graph
#   inflating: /content/text2mol/graph-data/raw/91859758.graph
#   inflating: /content/text2mol/graph-data/raw/91859760.graph
#   inflating: /content/text2mol/graph-data/raw/91859765.graph
#   inflating: /content/text2mol/graph-data/raw/91859766.graph
#   inflating: /content/text2mol/graph-data/raw/91859767.graph
#   inflating: /content/text2mol/graph-data/raw/91859771.graph
#   inflating: /content/text2mol/graph-data/raw/91859773.graph
#   inflating: /content/text2mol/graph-data/raw/91859776.graph
#   inflating: /content/text2mol/graph-data/raw/91859780.graph
#   inflating: /content/text2mol/graph-data/raw/91859781.graph
#   inflating: /content/text2mol/graph-data/raw/91859782.graph
#   inflating: /content/text2mol/graph-data/raw/91859785.graph
#   inflating: /content/text2mol/graph-data/raw/91859786.graph
#   inflating: /content/text2mol/graph-data/raw/91859787.graph
#   inflating: /content/text2mol/graph-data/raw/91859792.graph
#   inflating: /content/text2mol/graph-data/raw/91859794.graph
#   inflating: /content/text2mol/graph-data/raw/91859795.graph
#   inflating: /content/text2mol/graph-data/raw/91859796.graph
#   inflating: /content/text2mol/graph-data/raw/91859798.graph
#   inflating: /content/text2mol/graph-data/raw/91859799.graph
#   inflating: /content/text2mol/graph-data/raw/91859801.graph
#   inflating: /content/text2mol/graph-data/raw/91859802.graph
#   inflating: /content/text2mol/graph-data/raw/91859804.graph
#   inflating: /content/text2mol/graph-data/raw/91859811.graph
#   inflating: /content/text2mol/graph-data/raw/91859814.graph
#   inflating: /content/text2mol/graph-data/raw/91859818.graph
#   inflating: /content/text2mol/graph-data/raw/91859822.graph
#   inflating: /content/text2mol/graph-data/raw/91859824.graph
#   inflating: /content/text2mol/graph-data/raw/91859827.graph
#   inflating: /content/text2mol/graph-data/raw/91859830.graph
#   inflating: /content/text2mol/graph-data/raw/91859832.graph
#   inflating: /content/text2mol/graph-data/raw/91859833.graph
#   inflating: /content/text2mol/graph-data/raw/91859836.graph
#   inflating: /content/text2mol/graph-data/raw/91859838.graph
#   inflating: /content/text2mol/graph-data/raw/91859839.graph
#   inflating: /content/text2mol/graph-data/raw/91859840.graph
#   inflating: /content/text2mol/graph-data/raw/91859847.graph
#   inflating: /content/text2mol/graph-data/raw/91859851.graph
#   inflating: /content/text2mol/graph-data/raw/91859852.graph
#   inflating: /content/text2mol/graph-data/raw/91859853.graph
#   inflating: /content/text2mol/graph-data/raw/91859854.graph
#   inflating: /content/text2mol/graph-data/raw/91859855.graph
#   inflating: /content/text2mol/graph-data/raw/91859856.graph
#   inflating: /content/text2mol/graph-data/raw/91859859.graph
#   inflating: /content/text2mol/graph-data/raw/91859862.graph
#   inflating: /content/text2mol/graph-data/raw/91859863.graph
#   inflating: /content/text2mol/graph-data/raw/91859864.graph
#   inflating: /content/text2mol/graph-data/raw/91859866.graph
#   inflating: /content/text2mol/graph-data/raw/91859869.graph
#   inflating: /content/text2mol/graph-data/raw/91859875.graph
#   inflating: /content/text2mol/graph-data/raw/91859878.graph
#   inflating: /content/text2mol/graph-data/raw/91859880.graph
#   inflating: /content/text2mol/graph-data/raw/91859881.graph
#   inflating: /content/text2mol/graph-data/raw/91859886.graph
#   inflating: /content/text2mol/graph-data/raw/91859895.graph
#   inflating: /content/text2mol/graph-data/raw/91859903.graph
#   inflating: /content/text2mol/graph-data/raw/91859912.graph
#   inflating: /content/text2mol/graph-data/raw/91859917.graph
#   inflating: /content/text2mol/graph-data/raw/91859919.graph
#   inflating: /content/text2mol/graph-data/raw/91859923.graph
#   inflating: /content/text2mol/graph-data/raw/91859926.graph
#   inflating: /content/text2mol/graph-data/raw/91859927.graph
#   inflating: /content/text2mol/graph-data/raw/91859928.graph
#   inflating: /content/text2mol/graph-data/raw/91859930.graph
#   inflating: /content/text2mol/graph-data/raw/91859934.graph
#   inflating: /content/text2mol/graph-data/raw/91859939.graph
#   inflating: /content/text2mol/graph-data/raw/91859945.graph
#   inflating: /content/text2mol/graph-data/raw/91859946.graph
#   inflating: /content/text2mol/graph-data/raw/91859954.graph
#   inflating: /content/text2mol/graph-data/raw/91859957.graph
#   inflating: /content/text2mol/graph-data/raw/91859960.graph
#   inflating: /content/text2mol/graph-data/raw/91859962.graph
#   inflating: /content/text2mol/graph-data/raw/91859964.graph
#   inflating: /content/text2mol/graph-data/raw/91859970.graph
#   inflating: /content/text2mol/graph-data/raw/91859973.graph
#   inflating: /content/text2mol/graph-data/raw/91859979.graph
#   inflating: /content/text2mol/graph-data/raw/91859981.graph
#   inflating: /content/text2mol/graph-data/raw/91859984.graph
#   inflating: /content/text2mol/graph-data/raw/91859990.graph
#   inflating: /content/text2mol/graph-data/raw/91859992.graph
#   inflating: /content/text2mol/graph-data/raw/91859998.graph
#   inflating: /content/text2mol/graph-data/raw/91860001.graph
#   inflating: /content/text2mol/graph-data/raw/91860005.graph
#   inflating: /content/text2mol/graph-data/raw/91860006.graph
#   inflating: /content/text2mol/graph-data/raw/91860012.graph
#   inflating: /content/text2mol/graph-data/raw/91860013.graph
#   inflating: /content/text2mol/graph-data/raw/91860029.graph
#   inflating: /content/text2mol/graph-data/raw/91860032.graph
#   inflating: /content/text2mol/graph-data/raw/91860035.graph
#   inflating: /content/text2mol/graph-data/raw/91860042.graph
#   inflating: /content/text2mol/graph-data/raw/91860044.graph
#   inflating: /content/text2mol/graph-data/raw/91860047.graph
#   inflating: /content/text2mol/graph-data/raw/91860048.graph
#   inflating: /content/text2mol/graph-data/raw/91860051.graph
#   inflating: /content/text2mol/graph-data/raw/91860055.graph
#   inflating: /content/text2mol/graph-data/raw/91860058.graph
#   inflating: /content/text2mol/graph-data/raw/91860061.graph
#   inflating: /content/text2mol/graph-data/raw/91860062.graph
#   inflating: /content/text2mol/graph-data/raw/91860065.graph
#   inflating: /content/text2mol/graph-data/raw/91860067.graph
#   inflating: /content/text2mol/graph-data/raw/91860068.graph
#   inflating: /content/text2mol/graph-data/raw/91860077.graph
#   inflating: /content/text2mol/graph-data/raw/91860079.graph
#   inflating: /content/text2mol/graph-data/raw/91860081.graph
#   inflating: /content/text2mol/graph-data/raw/91860083.graph
#   inflating: /content/text2mol/graph-data/raw/91860084.graph
#   inflating: /content/text2mol/graph-data/raw/91860085.graph
#   inflating: /content/text2mol/graph-data/raw/91860091.graph
#   inflating: /content/text2mol/graph-data/raw/91860095.graph
#   inflating: /content/text2mol/graph-data/raw/91860104.graph
#   inflating: /content/text2mol/graph-data/raw/91860106.graph
#   inflating: /content/text2mol/graph-data/raw/91860107.graph
#   inflating: /content/text2mol/graph-data/raw/91860109.graph
#   inflating: /content/text2mol/graph-data/raw/91860110.graph
#   inflating: /content/text2mol/graph-data/raw/91860112.graph
#   inflating: /content/text2mol/graph-data/raw/91860114.graph
#   inflating: /content/text2mol/graph-data/raw/91860116.graph
#   inflating: /content/text2mol/graph-data/raw/91860117.graph
#   inflating: /content/text2mol/graph-data/raw/91860120.graph
#   inflating: /content/text2mol/graph-data/raw/91860128.graph
#   inflating: /content/text2mol/graph-data/raw/91860131.graph
#   inflating: /content/text2mol/graph-data/raw/91860134.graph
#   inflating: /content/text2mol/graph-data/raw/91860141.graph
#   inflating: /content/text2mol/graph-data/raw/91860143.graph
#   inflating: /content/text2mol/graph-data/raw/91860145.graph
#   inflating: /content/text2mol/graph-data/raw/91860146.graph
#   inflating: /content/text2mol/graph-data/raw/91860147.graph
#   inflating: /content/text2mol/graph-data/raw/91860150.graph
#   inflating: /content/text2mol/graph-data/raw/91860152.graph
#   inflating: /content/text2mol/graph-data/raw/91860156.graph
#   inflating: /content/text2mol/graph-data/raw/91860157.graph
#   inflating: /content/text2mol/graph-data/raw/91860159.graph
#   inflating: /content/text2mol/graph-data/raw/91860163.graph
#   inflating: /content/text2mol/graph-data/raw/91860165.graph
#   inflating: /content/text2mol/graph-data/raw/91860166.graph
#   inflating: /content/text2mol/graph-data/raw/91860167.graph
#   inflating: /content/text2mol/graph-data/raw/91860168.graph
#   inflating: /content/text2mol/graph-data/raw/91860172.graph
#   inflating: /content/text2mol/graph-data/raw/91860173.graph
#   inflating: /content/text2mol/graph-data/raw/91860183.graph
#   inflating: /content/text2mol/graph-data/raw/91860187.graph
#   inflating: /content/text2mol/graph-data/raw/91860190.graph
#   inflating: /content/text2mol/graph-data/raw/91860195.graph
#   inflating: /content/text2mol/graph-data/raw/91860199.graph
#   inflating: /content/text2mol/graph-data/raw/91860200.graph
#   inflating: /content/text2mol/graph-data/raw/91860201.graph
#   inflating: /content/text2mol/graph-data/raw/91860202.graph
#   inflating: /content/text2mol/graph-data/raw/91860203.graph
#   inflating: /content/text2mol/graph-data/raw/91860206.graph
#   inflating: /content/text2mol/graph-data/raw/91860208.graph
#   inflating: /content/text2mol/graph-data/raw/91860210.graph
#   inflating: /content/text2mol/graph-data/raw/91860212.graph
#   inflating: /content/text2mol/graph-data/raw/91860215.graph
#   inflating: /content/text2mol/graph-data/raw/91860217.graph
#   inflating: /content/text2mol/graph-data/raw/91860220.graph
#   inflating: /content/text2mol/graph-data/raw/91860228.graph
#   inflating: /content/text2mol/graph-data/raw/91860231.graph
#   inflating: /content/text2mol/graph-data/raw/91860232.graph
#   inflating: /content/text2mol/graph-data/raw/91860234.graph
#   inflating: /content/text2mol/graph-data/raw/91860236.graph
#   inflating: /content/text2mol/graph-data/raw/91860240.graph
#   inflating: /content/text2mol/graph-data/raw/91860242.graph
#   inflating: /content/text2mol/graph-data/raw/91860244.graph
#   inflating: /content/text2mol/graph-data/raw/91860245.graph
#   inflating: /content/text2mol/graph-data/raw/91860248.graph
#   inflating: /content/text2mol/graph-data/raw/91860249.graph
#   inflating: /content/text2mol/graph-data/raw/91860258.graph
#   inflating: /content/text2mol/graph-data/raw/91860261.graph
#   inflating: /content/text2mol/graph-data/raw/91860272.graph
#   inflating: /content/text2mol/graph-data/raw/91860273.graph
#   inflating: /content/text2mol/graph-data/raw/91860276.graph
#   inflating: /content/text2mol/graph-data/raw/91860279.graph
#   inflating: /content/text2mol/graph-data/raw/91860280.graph
#   inflating: /content/text2mol/graph-data/raw/91860285.graph
#   inflating: /content/text2mol/graph-data/raw/91860286.graph
#   inflating: /content/text2mol/graph-data/raw/91860288.graph
#   inflating: /content/text2mol/graph-data/raw/91860291.graph
#   inflating: /content/text2mol/graph-data/raw/91860292.graph
#   inflating: /content/text2mol/graph-data/raw/91860293.graph
#   inflating: /content/text2mol/graph-data/raw/91860298.graph
#   inflating: /content/text2mol/graph-data/raw/91860302.graph
#   inflating: /content/text2mol/graph-data/raw/91860303.graph
#   inflating: /content/text2mol/graph-data/raw/91860304.graph
#   inflating: /content/text2mol/graph-data/raw/91860310.graph
#   inflating: /content/text2mol/graph-data/raw/91860311.graph
#   inflating: /content/text2mol/graph-data/raw/91860313.graph
#   inflating: /content/text2mol/graph-data/raw/91860315.graph
#   inflating: /content/text2mol/graph-data/raw/91860321.graph
#   inflating: /content/text2mol/graph-data/raw/91860323.graph
#   inflating: /content/text2mol/graph-data/raw/91860328.graph
#   inflating: /content/text2mol/graph-data/raw/91860330.graph
#   inflating: /content/text2mol/graph-data/raw/91860331.graph
#   inflating: /content/text2mol/graph-data/raw/91860332.graph
#   inflating: /content/text2mol/graph-data/raw/91860333.graph
#   inflating: /content/text2mol/graph-data/raw/91860336.graph
#   inflating: /content/text2mol/graph-data/raw/91860337.graph
#   inflating: /content/text2mol/graph-data/raw/91860348.graph
#   inflating: /content/text2mol/graph-data/raw/91860350.graph
#   inflating: /content/text2mol/graph-data/raw/91860352.graph
#   inflating: /content/text2mol/graph-data/raw/91860354.graph
# ...
#   inflating: /content/text2mol/graph-data/raw/99564860.graph
#   inflating: /content/text2mol/graph-data/raw/9956637.graph
#   inflating: /content/text2mol/graph-data/raw/9956680.graph
#   inflating: /content/text2mol/graph-data/raw/9957280.graph
#   inflating: /content/text2mol/graph-data/raw/9957784.graph
#   inflating: /content/text2mol/graph-data/raw/9957785.graph
#   inflating: /content/text2mol/graph-data/raw/9957787.graph
#   inflating: /content/text2mol/graph-data/raw/9958.graph
#   inflating: /content/text2mol/graph-data/raw/9958186.graph
#   inflating: /content/text2mol/graph-data/raw/9958472.graph
#   inflating: /content/text2mol/graph-data/raw/9958939.graph
#   inflating: /content/text2mol/graph-data/raw/9959038.graph
#   inflating: /content/text2mol/graph-data/raw/9959307.graph
#   inflating: /content/text2mol/graph-data/raw/9959390.graph
#   inflating: /content/text2mol/graph-data/raw/9959532.graph
#   inflating: /content/text2mol/graph-data/raw/9959583.graph
#   inflating: /content/text2mol/graph-data/raw/99596.graph
#   inflating: /content/text2mol/graph-data/raw/996.graph
#   inflating: /content/text2mol/graph-data/raw/9960512.graph
#   inflating: /content/text2mol/graph-data/raw/9960605.graph
#   inflating: /content/text2mol/graph-data/raw/9960754.graph
#   inflating: /content/text2mol/graph-data/raw/9961192.graph
#   inflating: /content/text2mol/graph-data/raw/99613.graph
#   inflating: /content/text2mol/graph-data/raw/9961363.graph
#   inflating: /content/text2mol/graph-data/raw/99614.graph
#   inflating: /content/text2mol/graph-data/raw/9962077.graph
#   inflating: /content/text2mol/graph-data/raw/9962646.graph
#   inflating: /content/text2mol/graph-data/raw/9962735.graph
#   inflating: /content/text2mol/graph-data/raw/9963.graph
#   inflating: /content/text2mol/graph-data/raw/9963391.graph
#   inflating: /content/text2mol/graph-data/raw/9963743.graph
#   inflating: /content/text2mol/graph-data/raw/9963744.graph
#   inflating: /content/text2mol/graph-data/raw/9963963.graph
#   inflating: /content/text2mol/graph-data/raw/9963968.graph
#   inflating: /content/text2mol/graph-data/raw/9964.graph
#   inflating: /content/text2mol/graph-data/raw/9964159.graph
#   inflating: /content/text2mol/graph-data/raw/99642563.graph
#   inflating: /content/text2mol/graph-data/raw/9964514.graph
#   inflating: /content/text2mol/graph-data/raw/99647615.graph
#   inflating: /content/text2mol/graph-data/raw/9964843.graph
#   inflating: /content/text2mol/graph-data/raw/99649.graph
#   inflating: /content/text2mol/graph-data/raw/99650225.graph
#   inflating: /content/text2mol/graph-data/raw/99650674.graph
#   inflating: /content/text2mol/graph-data/raw/99650675.graph
#   inflating: /content/text2mol/graph-data/raw/99653.graph
#   inflating: /content/text2mol/graph-data/raw/9965325.graph
#   inflating: /content/text2mol/graph-data/raw/9966.graph
#   inflating: /content/text2mol/graph-data/raw/9966051.graph
#   inflating: /content/text2mol/graph-data/raw/9966159.graph
#   inflating: /content/text2mol/graph-data/raw/9966640.graph
#   inflating: /content/text2mol/graph-data/raw/9966861.graph
#   inflating: /content/text2mol/graph-data/raw/9967418.graph
#   inflating: /content/text2mol/graph-data/raw/9967861.graph
#   inflating: /content/text2mol/graph-data/raw/9967941.graph
#   inflating: /content/text2mol/graph-data/raw/9968.graph
#   inflating: /content/text2mol/graph-data/raw/9968846.graph
#   inflating: /content/text2mol/graph-data/raw/9969258.graph
#   inflating: /content/text2mol/graph-data/raw/9969573.graph
#   inflating: /content/text2mol/graph-data/raw/997.graph
#   inflating: /content/text2mol/graph-data/raw/997043.graph
#   inflating: /content/text2mol/graph-data/raw/9970764.graph
#   inflating: /content/text2mol/graph-data/raw/9971251.graph
#   inflating: /content/text2mol/graph-data/raw/99715.graph
#   inflating: /content/text2mol/graph-data/raw/99716.graph
#   inflating: /content/text2mol/graph-data/raw/99717.graph
#   inflating: /content/text2mol/graph-data/raw/99719.graph
#   inflating: /content/text2mol/graph-data/raw/9972600.graph
#   inflating: /content/text2mol/graph-data/raw/9972913.graph
#   inflating: /content/text2mol/graph-data/raw/9972939.graph
#   inflating: /content/text2mol/graph-data/raw/9973.graph
#   inflating: /content/text2mol/graph-data/raw/9973222.graph
#   inflating: /content/text2mol/graph-data/raw/99735.graph
#   inflating: /content/text2mol/graph-data/raw/9973540.graph
#   inflating: /content/text2mol/graph-data/raw/9974249.graph
#   inflating: /content/text2mol/graph-data/raw/9974373.graph
#   inflating: /content/text2mol/graph-data/raw/997451.graph
#   inflating: /content/text2mol/graph-data/raw/997475.graph
#   inflating: /content/text2mol/graph-data/raw/99748.graph
#   inflating: /content/text2mol/graph-data/raw/9975065.graph
#   inflating: /content/text2mol/graph-data/raw/9975455.graph
#   inflating: /content/text2mol/graph-data/raw/9975807.graph
#   inflating: /content/text2mol/graph-data/raw/9977239.graph
#   inflating: /content/text2mol/graph-data/raw/9977422.graph
#   inflating: /content/text2mol/graph-data/raw/9978057.graph
#   inflating: /content/text2mol/graph-data/raw/9978336.graph
#   inflating: /content/text2mol/graph-data/raw/998.graph
#   inflating: /content/text2mol/graph-data/raw/998000.graph
#   inflating: /content/text2mol/graph-data/raw/9980241.graph
#   inflating: /content/text2mol/graph-data/raw/9982.graph
#   inflating: /content/text2mol/graph-data/raw/9982218.graph
#   inflating: /content/text2mol/graph-data/raw/9982260.graph
#   inflating: /content/text2mol/graph-data/raw/99823.graph
#   inflating: /content/text2mol/graph-data/raw/99824.graph
#   inflating: /content/text2mol/graph-data/raw/9982878.graph
#   inflating: /content/text2mol/graph-data/raw/9983046.graph
#   inflating: /content/text2mol/graph-data/raw/9983303.graph
#   inflating: /content/text2mol/graph-data/raw/9984208.graph
#   inflating: /content/text2mol/graph-data/raw/9984420.graph
#   inflating: /content/text2mol/graph-data/raw/99856.graph
#   inflating: /content/text2mol/graph-data/raw/9986191.graph
#   inflating: /content/text2mol/graph-data/raw/9986192.graph
#   inflating: /content/text2mol/graph-data/raw/9986397.graph
#   inflating: /content/text2mol/graph-data/raw/9986398.graph
#   inflating: /content/text2mol/graph-data/raw/9986495.graph
#   inflating: /content/text2mol/graph-data/raw/9986866.graph
#   inflating: /content/text2mol/graph-data/raw/9987638.graph
#   inflating: /content/text2mol/graph-data/raw/9988405.graph
#   inflating: /content/text2mol/graph-data/raw/9988471.graph
#   inflating: /content/text2mol/graph-data/raw/9988606.graph
#   inflating: /content/text2mol/graph-data/raw/9988748.graph
#   inflating: /content/text2mol/graph-data/raw/998878.graph
#   inflating: /content/text2mol/graph-data/raw/998884.graph
#   inflating: /content/text2mol/graph-data/raw/99889.graph
#   inflating: /content/text2mol/graph-data/raw/998899.graph
#   inflating: /content/text2mol/graph-data/raw/9989023.graph
#   inflating: /content/text2mol/graph-data/raw/9989219.graph
#   inflating: /content/text2mol/graph-data/raw/9989505.graph
#   inflating: /content/text2mol/graph-data/raw/999.graph
#   inflating: /content/text2mol/graph-data/raw/9991606.graph
#   inflating: /content/text2mol/graph-data/raw/99918308.graph
#   inflating: /content/text2mol/graph-data/raw/9993.graph
#   inflating: /content/text2mol/graph-data/raw/99931.graph
#   inflating: /content/text2mol/graph-data/raw/9993281.graph
#   inflating: /content/text2mol/graph-data/raw/9993419.graph
#   inflating: /content/text2mol/graph-data/raw/999345.graph
#   inflating: /content/text2mol/graph-data/raw/9994677.graph
#   inflating: /content/text2mol/graph-data/raw/9995890.graph
#   inflating: /content/text2mol/graph-data/raw/9996586.graph
#   inflating: /content/text2mol/graph-data/raw/9996708.graph
#   inflating: /content/text2mol/graph-data/raw/9997.graph
#   inflating: /content/text2mol/graph-data/raw/9997028.graph
#   inflating: /content/text2mol/graph-data/raw/9997821.graph
#   inflating: /content/text2mol/graph-data/raw/9998041.graph
#   inflating: /content/text2mol/graph-data/raw/9998639.graph
#   inflating: /content/text2mol/graph-data/raw/9999.graph
#   inflating: /content/text2mol/graph-data/raw/9999819.graph
#    creating: /content/text2mol/inputs/
#    creating: /content/text2mol/inputs/GCN1/
#    creating: /content/text2mol/inputs/GCN1/embeddings/
#   inflating: /content/text2mol/inputs/GCN1/embeddings/chem_embeddings_test.npy
#   inflating: /content/text2mol/inputs/GCN1/embeddings/chem_embeddings_train.npy
#   inflating: /content/text2mol/inputs/GCN1/embeddings/chem_embeddings_val.npy
#   inflating: /content/text2mol/inputs/GCN1/embeddings/cids_test.npy
#   inflating: /content/text2mol/inputs/GCN1/embeddings/cids_train.npy
#   inflating: /content/text2mol/inputs/GCN1/embeddings/cids_val.npy
#   inflating: /content/text2mol/inputs/GCN1/embeddings/text_embeddings_test.npy
#   inflating: /content/text2mol/inputs/GCN1/embeddings/text_embeddings_train.npy
#   inflating: /content/text2mol/inputs/GCN1/embeddings/text_embeddings_val.npy
#    creating: /content/text2mol/inputs/GCN2/
#    creating: /content/text2mol/inputs/GCN2/embeddings/
#   inflating: /content/text2mol/inputs/GCN2/embeddings/chem_embeddings_test.npy
#   inflating: /content/text2mol/inputs/GCN2/embeddings/chem_embeddings_train.npy
#   inflating: /content/text2mol/inputs/GCN2/embeddings/chem_embeddings_val.npy
#   inflating: /content/text2mol/inputs/GCN2/embeddings/cids_test.npy
#   inflating: /content/text2mol/inputs/GCN2/embeddings/cids_train.npy
#   inflating: /content/text2mol/inputs/GCN2/embeddings/cids_val.npy
#   inflating: /content/text2mol/inputs/GCN2/embeddings/text_embeddings_test.npy
#   inflating: /content/text2mol/inputs/GCN2/embeddings/text_embeddings_train.npy
#   inflating: /content/text2mol/inputs/GCN2/embeddings/text_embeddings_val.npy
#    creating: /content/text2mol/inputs/GCN3/
#    creating: /content/text2mol/inputs/GCN3/embeddings/
#   inflating: /content/text2mol/inputs/GCN3/embeddings/chem_embeddings_test.npy
#   inflating: /content/text2mol/inputs/GCN3/embeddings/chem_embeddings_train.npy
#   inflating: /content/text2mol/inputs/GCN3/embeddings/chem_embeddings_val.npy
#   inflating: /content/text2mol/inputs/GCN3/embeddings/cids_test.npy
#   inflating: /content/text2mol/inputs/GCN3/embeddings/cids_train.npy
#   inflating: /content/text2mol/inputs/GCN3/embeddings/cids_val.npy
#   inflating: /content/text2mol/inputs/GCN3/embeddings/text_embeddings_test.npy
#   inflating: /content/text2mol/inputs/GCN3/embeddings/text_embeddings_train.npy
#   inflating: /content/text2mol/inputs/GCN3/embeddings/text_embeddings_val.npy
#    creating: /content/text2mol/inputs/GCN4/
#    creating: /content/text2mol/inputs/GCN4/embeddings/
#   inflating: /content/text2mol/inputs/GCN4/embeddings/chem_embeddings_test.npy
#   inflating: /content/text2mol/inputs/GCN4/embeddings/chem_embeddings_train.npy
#   inflating: /content/text2mol/inputs/GCN4/embeddings/chem_embeddings_val.npy
#   inflating: /content/text2mol/inputs/GCN4/embeddings/cids_test.npy
#   inflating: /content/text2mol/inputs/GCN4/embeddings/cids_train.npy
#   inflating: /content/text2mol/inputs/GCN4/embeddings/cids_val.npy
#   inflating: /content/text2mol/inputs/GCN4/embeddings/text_embeddings_test.npy
#   inflating: /content/text2mol/inputs/GCN4/embeddings/text_embeddings_train.npy
#   inflating: /content/text2mol/inputs/GCN4/embeddings/text_embeddings_val.npy
#    creating: /content/text2mol/inputs/MLP1/
#    creating: /content/text2mol/inputs/MLP1/embeddings/
#   inflating: /content/text2mol/inputs/MLP1/embeddings/chem_embeddings_test.npy
#   inflating: /content/text2mol/inputs/MLP1/embeddings/chem_embeddings_train.npy
#   inflating: /content/text2mol/inputs/MLP1/embeddings/chem_embeddings_val.npy
#   inflating: /content/text2mol/inputs/MLP1/embeddings/cids_test.npy
#   inflating: /content/text2mol/inputs/MLP1/embeddings/cids_train.npy
#   inflating: /content/text2mol/inputs/MLP1/embeddings/cids_val.npy
#   inflating: /content/text2mol/inputs/MLP1/embeddings/text_embeddings_test.npy
#   inflating: /content/text2mol/inputs/MLP1/embeddings/text_embeddings_train.npy
#   inflating: /content/text2mol/inputs/MLP1/embeddings/text_embeddings_val.npy
#    creating: /content/text2mol/inputs/MLP2/
#    creating: /content/text2mol/inputs/MLP2/embeddings/
#   inflating: /content/text2mol/inputs/MLP2/embeddings/chem_embeddings_test.npy
#   inflating: /content/text2mol/inputs/MLP2/embeddings/chem_embeddings_train.npy
#   inflating: /content/text2mol/inputs/MLP2/embeddings/chem_embeddings_val.npy
#   inflating: /content/text2mol/inputs/MLP2/embeddings/cids_test.npy
#   inflating: /content/text2mol/inputs/MLP2/embeddings/cids_train.npy
#   inflating: /content/text2mol/inputs/MLP2/embeddings/cids_val.npy
#   inflating: /content/text2mol/inputs/MLP2/embeddings/text_embeddings_test.npy
#   inflating: /content/text2mol/inputs/MLP2/embeddings/text_embeddings_train.npy
#   inflating: /content/text2mol/inputs/MLP2/embeddings/text_embeddings_val.npy
#    creating: /content/text2mol/inputs/MLP3/
#    creating: /content/text2mol/inputs/MLP3/embeddings/
#   inflating: /content/text2mol/inputs/MLP3/embeddings/chem_embeddings_test.npy
#   inflating: /content/text2mol/inputs/MLP3/embeddings/chem_embeddings_train.npy
#   inflating: /content/text2mol/inputs/MLP3/embeddings/chem_embeddings_val.npy
#   inflating: /content/text2mol/inputs/MLP3/embeddings/cids_test.npy
#   inflating: /content/text2mol/inputs/MLP3/embeddings/cids_train.npy
#   inflating: /content/text2mol/inputs/MLP3/embeddings/cids_val.npy
#   inflating: /content/text2mol/inputs/MLP3/embeddings/text_embeddings_test.npy
#   inflating: /content/text2mol/inputs/MLP3/embeddings/text_embeddings_train.npy
#   inflating: /content/text2mol/inputs/MLP3/embeddings/text_embeddings_val.npy
#    creating: /content/text2mol/inputs/MLP4/
#    creating: /content/text2mol/inputs/MLP4/embeddings/
#   inflating: /content/text2mol/inputs/MLP4/embeddings/chem_embeddings_test.npy
#   inflating: /content/text2mol/inputs/MLP4/embeddings/chem_embeddings_train.npy
#   inflating: /content/text2mol/inputs/MLP4/embeddings/chem_embeddings_val.npy
#   inflating: /content/text2mol/inputs/MLP4/embeddings/cids_test.npy
#   inflating: /content/text2mol/inputs/MLP4/embeddings/cids_train.npy
#   inflating: /content/text2mol/inputs/MLP4/embeddings/cids_val.npy
#   inflating: /content/text2mol/inputs/MLP4/embeddings/text_embeddings_test.npy
#   inflating: /content/text2mol/inputs/MLP4/embeddings/text_embeddings_train.npy
#   inflating: /content/text2mol/inputs/MLP4/embeddings/text_embeddings_val.npy
#    creating: /content/text2mol/misc/
#   inflating: /content/text2mol/misc/task2.PNG
#   inflating: /content/text2mol/misc/Text2Mol_EMNLP_poster.png
#   inflating: /content/text2mol/misc/Text2Mol_EMNLP_poster_cropped_for_printing.pdf
#    creating: /content/text2mol/MLP1_output/
#    creating: /content/text2mol/MLP1_output/embeddings/
#   inflating: /content/text2mol/MLP1_output/embeddings/chem_embeddings_test.npy
#   inflating: /content/text2mol/MLP1_output/embeddings/chem_embeddings_train.npy
#   inflating: /content/text2mol/MLP1_output/embeddings/chem_embeddings_val.npy
#   inflating: /content/text2mol/MLP1_output/embeddings/cids_test.npy
#   inflating: /content/text2mol/MLP1_output/embeddings/cids_train.npy
#   inflating: /content/text2mol/MLP1_output/embeddings/cids_val.npy
#   inflating: /content/text2mol/MLP1_output/embeddings/text_embeddings_test.npy
#   inflating: /content/text2mol/MLP1_output/embeddings/text_embeddings_train.npy
#   inflating: /content/text2mol/MLP1_output/embeddings/text_embeddings_val.npy
#   inflating: /content/text2mol/MLP1_output/final_weights.40.pt
#   inflating: /content/text2mol/README.md
#   inflating: /content/text2mol/results.csv
# Download and unzip complete!

# %%
import os
import shutil

import numpy as np

import matplotlib.pyplot as plt

import math

# %%
dir1 = "inputs/GCN1/embeddings/"
dir2 = "inputs/GCN2/embeddings/"
dir3 = "inputs/GCN3/embeddings/"
dir4 = "inputs/MLP1/embeddings/"
dir5 = "inputs/MLP2/embeddings/"
dir6 = "inputs/MLP3/embeddings/"

# CHANGE START
dir7 = "inputs/GCN4/embeddings/"
dir8 = "inputs/MLP4/embeddings/"
# CHANGE END

cids_train1 = np.load(dir1 + "cids_train.npy", allow_pickle=True)
cids_val1 = np.load(dir1 + "cids_val.npy", allow_pickle=True)
cids_test1 = np.load(dir1 + "cids_test.npy", allow_pickle=True)

chem_embeddings_train1 = np.load(dir1 + "chem_embeddings_train.npy")
chem_embeddings_val1 = np.load(dir1 + "chem_embeddings_val.npy")
chem_embeddings_test1 = np.load(dir1 + "chem_embeddings_test.npy")
text_embeddings_train1 = np.load(dir1 + "text_embeddings_train.npy")
text_embeddings_val1 = np.load(dir1 + "text_embeddings_val.npy")
text_embeddings_test1 = np.load(dir1 + "text_embeddings_test.npy")

cids_train2 = np.load(dir2 + "cids_train.npy", allow_pickle=True)
cids_val2 = np.load(dir2 + "cids_val.npy", allow_pickle=True)
cids_test2 = np.load(dir2 + "cids_test.npy", allow_pickle=True)

chem_embeddings_train2 = np.load(dir2 + "chem_embeddings_train.npy")
chem_embeddings_val2 = np.load(dir2 + "chem_embeddings_val.npy")
chem_embeddings_test2 = np.load(dir2 + "chem_embeddings_test.npy")
text_embeddings_train2 = np.load(dir2 + "text_embeddings_train.npy")
text_embeddings_val2 = np.load(dir2 + "text_embeddings_val.npy")
text_embeddings_test2 = np.load(dir2 + "text_embeddings_test.npy")

cids_train3 = np.load(dir3 + "cids_train.npy", allow_pickle=True)
cids_val3 = np.load(dir3 + "cids_val.npy", allow_pickle=True)
cids_test3 = np.load(dir3 + "cids_test.npy", allow_pickle=True)

chem_embeddings_train3 = np.load(dir3 + "chem_embeddings_train.npy")
chem_embeddings_val3 = np.load(dir3 + "chem_embeddings_val.npy")
chem_embeddings_test3 = np.load(dir3 + "chem_embeddings_test.npy")
text_embeddings_train3 = np.load(dir3 + "text_embeddings_train.npy")
text_embeddings_val3 = np.load(dir3 + "text_embeddings_val.npy")
text_embeddings_test3 = np.load(dir3 + "text_embeddings_test.npy")

cids_train4 = np.load(dir4 + "cids_train.npy", allow_pickle=True)
cids_val4 = np.load(dir4 + "cids_val.npy", allow_pickle=True)
cids_test4 = np.load(dir4 + "cids_test.npy", allow_pickle=True)

chem_embeddings_train4 = np.load(dir4 + "chem_embeddings_train.npy")
chem_embeddings_val4 = np.load(dir4 + "chem_embeddings_val.npy")
chem_embeddings_test4 = np.load(dir4 + "chem_embeddings_test.npy")
text_embeddings_train4 = np.load(dir4 + "text_embeddings_train.npy")
text_embeddings_val4 = np.load(dir4 + "text_embeddings_val.npy")
text_embeddings_test4 = np.load(dir4 + "text_embeddings_test.npy")

cids_train5 = np.load(dir5 + "cids_train.npy", allow_pickle=True)
cids_val5 = np.load(dir5 + "cids_val.npy", allow_pickle=True)
cids_test5 = np.load(dir5 + "cids_test.npy", allow_pickle=True)

chem_embeddings_train5 = np.load(dir5 + "chem_embeddings_train.npy")
chem_embeddings_val5 = np.load(dir5 + "chem_embeddings_val.npy")
chem_embeddings_test5 = np.load(dir5 + "chem_embeddings_test.npy")
text_embeddings_train5 = np.load(dir5 + "text_embeddings_train.npy")
text_embeddings_val5 = np.load(dir5 + "text_embeddings_val.npy")
text_embeddings_test5 = np.load(dir5 + "text_embeddings_test.npy")

cids_train6 = np.load(dir6 + "cids_train.npy", allow_pickle=True)
cids_val6 = np.load(dir6 + "cids_val.npy", allow_pickle=True)
cids_test6 = np.load(dir6 + "cids_test.npy", allow_pickle=True)

chem_embeddings_train6 = np.load(dir6 + "chem_embeddings_train.npy")
chem_embeddings_val6 = np.load(dir6 + "chem_embeddings_val.npy")
chem_embeddings_test6 = np.load(dir6 + "chem_embeddings_test.npy")
text_embeddings_train6 = np.load(dir6 + "text_embeddings_train.npy")
text_embeddings_val6 = np.load(dir6 + "text_embeddings_val.npy")
text_embeddings_test6 = np.load(dir6 + "text_embeddings_test.npy")

# CHANGE START
cids_train7 = np.load(dir7 + "cids_train.npy", allow_pickle=True)
cids_val7 = np.load(dir7 + "cids_val.npy", allow_pickle=True)
cids_test7 = np.load(dir7 + "cids_test.npy", allow_pickle=True)

chem_embeddings_train7 = np.load(dir7 + "chem_embeddings_train.npy")
chem_embeddings_val7 = np.load(dir7 + "chem_embeddings_val.npy")
chem_embeddings_test7 = np.load(dir7 + "chem_embeddings_test.npy")
text_embeddings_train7 = np.load(dir7 + "text_embeddings_train.npy")
text_embeddings_val7 = np.load(dir7 + "text_embeddings_val.npy")
text_embeddings_test7 = np.load(dir7 + "text_embeddings_test.npy")

cids_train8 = np.load(dir8 + "cids_train.npy", allow_pickle=True)
cids_val8 = np.load(dir8 + "cids_val.npy", allow_pickle=True)
cids_test8 = np.load(dir8 + "cids_test.npy", allow_pickle=True)

chem_embeddings_train8 = np.load(dir8 + "chem_embeddings_train.npy")
chem_embeddings_val8 = np.load(dir8 + "chem_embeddings_val.npy")
chem_embeddings_test8 = np.load(dir8 + "chem_embeddings_test.npy")
text_embeddings_train8 = np.load(dir8 + "text_embeddings_train.npy")
text_embeddings_val8 = np.load(dir8 + "text_embeddings_val.npy")
text_embeddings_test8 = np.load(dir8 + "text_embeddings_test.npy")
# CHANGE END

#Reorder (this is very important):
tmp = cids_train2.tolist()
indexes = [tmp.index(i) for i in cids_train1]
tmp = cids_val2.tolist()
indexes_val = [tmp.index(i) for i in cids_val1]
tmp = cids_test2.tolist()
indexes_test = [tmp.index(i) for i in cids_test1]

cids_train2 = cids_train2[indexes]
cids_val2 = cids_val2[indexes_val]
cids_test2 = cids_test2[indexes_test]

chem_embeddings_train2 = chem_embeddings_train2[indexes]
text_embeddings_train2 = text_embeddings_train2[indexes]
chem_embeddings_val2 = chem_embeddings_val2[indexes_val]
text_embeddings_val2 = text_embeddings_val2[indexes_val]
chem_embeddings_test2 = chem_embeddings_test2[indexes_test]
text_embeddings_test2 = text_embeddings_test2[indexes_test]


tmp = cids_train3.tolist()
indexes = [tmp.index(i) for i in cids_train1]
tmp = cids_val3.tolist()
indexes_val = [tmp.index(i) for i in cids_val1]
tmp = cids_test3.tolist()
indexes_test = [tmp.index(i) for i in cids_test1]

cids_train3 = cids_train3[indexes]
cids_val3 = cids_val3[indexes_val]
cids_test3 = cids_test3[indexes_test]

chem_embeddings_train3 = chem_embeddings_train3[indexes]
text_embeddings_train3 = text_embeddings_train3[indexes]
chem_embeddings_val3 = chem_embeddings_val3[indexes_val]
text_embeddings_val3 = text_embeddings_val3[indexes_val]
chem_embeddings_test3 = chem_embeddings_test3[indexes_test]
text_embeddings_test3 = text_embeddings_test3[indexes_test]


tmp = cids_train4.tolist()
indexes = [tmp.index(i) for i in cids_train1]
tmp = cids_val4.tolist()
indexes_val = [tmp.index(i) for i in cids_val1]
tmp = cids_test4.tolist()
indexes_test = [tmp.index(i) for i in cids_test1]

cids_train4 = cids_train4[indexes]
cids_val4 = cids_val4[indexes_val]
cids_test4 = cids_test4[indexes_test]

chem_embeddings_train4 = chem_embeddings_train4[indexes]
text_embeddings_train4 = text_embeddings_train4[indexes]
chem_embeddings_val4 = chem_embeddings_val4[indexes_val]
text_embeddings_val4 = text_embeddings_val4[indexes_val]
chem_embeddings_test4 = chem_embeddings_test4[indexes_test]
text_embeddings_test4 = text_embeddings_test4[indexes_test]


tmp = cids_train5.tolist()
indexes = [tmp.index(i) for i in cids_train1]
tmp = cids_val5.tolist()
indexes_val = [tmp.index(i) for i in cids_val1]
tmp = cids_test5.tolist()
indexes_test = [tmp.index(i) for i in cids_test1]

cids_train5 = cids_train5[indexes]
cids_val5 = cids_val5[indexes_val]
cids_test5 = cids_test5[indexes_test]

chem_embeddings_train5 = chem_embeddings_train5[indexes]
text_embeddings_train5 = text_embeddings_train5[indexes]
chem_embeddings_val5 = chem_embeddings_val5[indexes_val]
text_embeddings_val5 = text_embeddings_val5[indexes_val]
chem_embeddings_test5 = chem_embeddings_test5[indexes_test]
text_embeddings_test5 = text_embeddings_test5[indexes_test]


tmp = cids_train6.tolist()
indexes = [tmp.index(i) for i in cids_train1]
tmp = cids_val6.tolist()
indexes_val = [tmp.index(i) for i in cids_val1]
tmp = cids_test6.tolist()
indexes_test = [tmp.index(i) for i in cids_test1]

cids_train6 = cids_train6[indexes]
cids_val6 = cids_val6[indexes_val]
cids_test6 = cids_test6[indexes_test]

chem_embeddings_train6 = chem_embeddings_train6[indexes]
text_embeddings_train6 = text_embeddings_train6[indexes]
chem_embeddings_val6 = chem_embeddings_val6[indexes_val]
text_embeddings_val6 = text_embeddings_val6[indexes_val]
chem_embeddings_test6 = chem_embeddings_test6[indexes_test]
text_embeddings_test6 = text_embeddings_test6[indexes_test]

# CHANGE START
tmp = cids_train7.tolist()
indexes = [tmp.index(i) for i in cids_train1]
tmp = cids_val7.tolist()
indexes_val = [tmp.index(i) for i in cids_val1]
tmp = cids_test7.tolist()
indexes_test = [tmp.index(i) for i in cids_test1]

cids_train7 = cids_train7[indexes]
cids_val7 = cids_val7[indexes_val]
cids_test7 = cids_test7[indexes_test]

chem_embeddings_train7 = chem_embeddings_train7[indexes]
text_embeddings_train7 = text_embeddings_train7[indexes]
chem_embeddings_val7 = chem_embeddings_val7[indexes_val]
text_embeddings_val7 = text_embeddings_val7[indexes_val]
chem_embeddings_test7 = chem_embeddings_test7[indexes_test]
text_embeddings_test7 = text_embeddings_test7[indexes_test]

tmp = cids_train8.tolist()
indexes = [tmp.index(i) for i in cids_train1]
tmp = cids_val8.tolist()
indexes_val = [tmp.index(i) for i in cids_val1]
tmp = cids_test8.tolist()
indexes_test = [tmp.index(i) for i in cids_test1]

cids_train8 = cids_train8[indexes]
cids_val8 = cids_val8[indexes_val]
cids_test8 = cids_test8[indexes_test]

chem_embeddings_train8 = chem_embeddings_train8[indexes]
text_embeddings_train8 = text_embeddings_train8[indexes]
chem_embeddings_val8 = chem_embeddings_val8[indexes_val]
text_embeddings_val8 = text_embeddings_val8[indexes_val]
chem_embeddings_test8 = chem_embeddings_test8[indexes_test]
text_embeddings_test8 = text_embeddings_test8[indexes_test]
# CHANGE END

all_chem_embbedings1 = np.concatenate((chem_embeddings_train1, chem_embeddings_val1, chem_embeddings_test1), axis = 0)
all_chem_embbedings2 = np.concatenate((chem_embeddings_train2, chem_embeddings_val2, chem_embeddings_test2), axis = 0)
all_chem_embbedings3 = np.concatenate((chem_embeddings_train3, chem_embeddings_val3, chem_embeddings_test3), axis = 0)
all_chem_embbedings4 = np.concatenate((chem_embeddings_train4, chem_embeddings_val4, chem_embeddings_test4), axis = 0)
all_chem_embbedings5 = np.concatenate((chem_embeddings_train5, chem_embeddings_val5, chem_embeddings_test5), axis = 0)
all_chem_embbedings6 = np.concatenate((chem_embeddings_train6, chem_embeddings_val6, chem_embeddings_test6), axis = 0)

# CHANGE START
all_chem_embbedings7 = np.concatenate((chem_embeddings_train7, chem_embeddings_val7, chem_embeddings_test7), axis = 0)
all_chem_embbedings8 = np.concatenate((chem_embeddings_train8, chem_embeddings_val8, chem_embeddings_test8), axis = 0)
# CHANGE END

# %%
from sklearn.metrics.pairwise import cosine_similarity

def memory_efficient_similarity_matrix_custom(func, embedding1, embedding2, chunk_size = 1000):
    rows = embedding1.shape[0]

    num_chunks = int(np.ceil(rows / chunk_size))

    for i in range(num_chunks):
        end_chunk = (i+1)*(chunk_size) if (i+1)*(chunk_size) < rows else rows #account for smaller chunk at end...
        yield func(embedding1[i*chunk_size:end_chunk,:], embedding2)


text_chem_cos1 = memory_efficient_similarity_matrix_custom(cosine_similarity, text_embeddings_train1, all_chem_embbedings1)
text_chem_cos_val1 = memory_efficient_similarity_matrix_custom(cosine_similarity, text_embeddings_val1, all_chem_embbedings1)
text_chem_cos_test1 = memory_efficient_similarity_matrix_custom(cosine_similarity, text_embeddings_test1, all_chem_embbedings1)

text_chem_cos2 = memory_efficient_similarity_matrix_custom(cosine_similarity, text_embeddings_train2, all_chem_embbedings2)
text_chem_cos_val2 = memory_efficient_similarity_matrix_custom(cosine_similarity, text_embeddings_val2, all_chem_embbedings2)
text_chem_cos_test2 = memory_efficient_similarity_matrix_custom(cosine_similarity, text_embeddings_test2, all_chem_embbedings2)

text_chem_cos3 = memory_efficient_similarity_matrix_custom(cosine_similarity, text_embeddings_train3, all_chem_embbedings3)
text_chem_cos_val3 = memory_efficient_similarity_matrix_custom(cosine_similarity, text_embeddings_val3, all_chem_embbedings3)
text_chem_cos_test3 = memory_efficient_similarity_matrix_custom(cosine_similarity, text_embeddings_test3, all_chem_embbedings3)

text_chem_cos4 = memory_efficient_similarity_matrix_custom(cosine_similarity, text_embeddings_train4, all_chem_embbedings4)
text_chem_cos_val4 = memory_efficient_similarity_matrix_custom(cosine_similarity, text_embeddings_val4, all_chem_embbedings4)
text_chem_cos_test4 = memory_efficient_similarity_matrix_custom(cosine_similarity, text_embeddings_test4, all_chem_embbedings4)

text_chem_cos5 = memory_efficient_similarity_matrix_custom(cosine_similarity, text_embeddings_train5, all_chem_embbedings5)
text_chem_cos_val5 = memory_efficient_similarity_matrix_custom(cosine_similarity, text_embeddings_val5, all_chem_embbedings5)
text_chem_cos_test5 = memory_efficient_similarity_matrix_custom(cosine_similarity, text_embeddings_test5, all_chem_embbedings5)

text_chem_cos6 = memory_efficient_similarity_matrix_custom(cosine_similarity, text_embeddings_train6, all_chem_embbedings6)
text_chem_cos_val6 = memory_efficient_similarity_matrix_custom(cosine_similarity, text_embeddings_val6, all_chem_embbedings6)
text_chem_cos_test6 = memory_efficient_similarity_matrix_custom(cosine_similarity, text_embeddings_test6, all_chem_embbedings6)

# CHANGE START
text_chem_cos7 = memory_efficient_similarity_matrix_custom(cosine_similarity, text_embeddings_train7, all_chem_embbedings7)
text_chem_cos_val7 = memory_efficient_similarity_matrix_custom(cosine_similarity, text_embeddings_val7, all_chem_embbedings7)
text_chem_cos_test7 = memory_efficient_similarity_matrix_custom(cosine_similarity, text_embeddings_test7, all_chem_embbedings7)

text_chem_cos8 = memory_efficient_similarity_matrix_custom(cosine_similarity, text_embeddings_train8, all_chem_embbedings8)
text_chem_cos_val8 = memory_efficient_similarity_matrix_custom(cosine_similarity, text_embeddings_val8, all_chem_embbedings8)
text_chem_cos_test8 = memory_efficient_similarity_matrix_custom(cosine_similarity, text_embeddings_test8, all_chem_embbedings8)
# CHANGE END

# %%
n_train = len(cids_train1)
n_val = len(cids_val2)
n_test = len(cids_test1)
n = n_train + n_val + n_test

offset_val = n_train
offset_test = n_train + n_val

cids_all = np.concatenate((cids_train1, cids_val1, cids_test1), axis = 0)

# %%
tr_ranks_avg = np.zeros((n_train, n))

# %%
val_avg_ranks = np.zeros((n_val, n))
test_avg_ranks = np.zeros((n_test, n))

# %%
#For space 1:


tr_correct1 = np.zeros(len(cids_train1))

hits_at_one = 0
hits_at_ten = 0
hits_at_100 = 0
hits_at_500 = 0
hits_at_1000 = 0
ranks1 = []
j = 0 #keep track of all loops
for i, emb in enumerate(text_chem_cos1):
    for k in range(emb.shape[0]):
        cid_locs = np.argsort(emb[k,:])[::-1]
        ranks = np.argsort(cid_locs) #rank is actually double argsort.

        tr_ranks_avg[j,:] = tr_ranks_avg[j,:] + ranks


        tr_correct1[j] = ranks[j] + 1
        rank = ranks[j] + 1
        ranks1.append(rank)


        j += 1
        if (j) % 1000 == 0: print((j), "train processed.")

ranks1 = np.array(ranks1)

print()
print("Training Mean rank:", np.mean(ranks1))
print("Hits at 1:", np.mean(ranks1 <= 1))
print("Hits at 10:", np.mean(ranks1 <= 10))
print("Hits at 100:", np.mean(ranks1 <= 100))
print("Hits at 500:", np.mean(ranks1 <= 500))
print("Hits at 1000:", np.mean(ranks1 <= 1000))

print("Trainng MRR:", np.mean(1/np.array(ranks1)))
# Out:
# 1000 train processed.
# 2000 train processed.
# 3000 train processed.
# 4000 train processed.
# 5000 train processed.
# 6000 train processed.
# 7000 train processed.
# 8000 train processed.
# 9000 train processed.
# 10000 train processed.
# 11000 train processed.
# 12000 train processed.
# 13000 train processed.
# 14000 train processed.
# 15000 train processed.
# 16000 train processed.
# 17000 train processed.
# 18000 train processed.
# 19000 train processed.
# 20000 train processed.
# 21000 train processed.
# 22000 train processed.
# 23000 train processed.
# 24000 train processed.
# 25000 train processed.
# 26000 train processed.
#
# Training Mean rank: 3.7838533777643137
# Hits at 1: 0.42562859739472886
# Hits at 10: 0.9326340502877916
# Hits at 100: 0.9996591941835807
# Hits at 500: 1.0
# Hits at 1000: 1.0
# Trainng MRR: 0.5978082812849088

# %%
ranks_val1 = []
j = 0 #keep track of all loops
for i, emb in enumerate(text_chem_cos_val1):
    for k in range(emb.shape[0]):
        cid_locs = np.argsort(emb[k,:])[::-1]
        ranks = np.argsort(cid_locs)

        val_avg_ranks[j,:] = val_avg_ranks[j,:] + ranks

        rank = ranks[j+offset_val] + 1
        ranks_val1.append(rank)

        j += 1
        if (j) % 1000 == 0: print((j), "val processed.")


ranks_val1 = np.array(ranks_val1)

print()
print("Val Mean rank:", np.mean(ranks_val1))
print("Hits at 1:", np.mean(ranks_val1 <= 1))
print("Hits at 10:", np.mean(ranks_val1 <= 10))
print("Hits at 100:", np.mean(ranks_val1 <= 100))
print("Hits at 500:", np.mean(ranks_val1 <= 500))
print("Hits at 1000:", np.mean(ranks_val1 <= 1000))

print("Validation MRR:", np.mean(1/ranks_val1))
# Out:
# 1000 val processed.
# 2000 val processed.
# 3000 val processed.
#
# Val Mean rank: 29.38018782187216
# Hits at 1: 0.3232353832172069
# Hits at 10: 0.8218721599515298
# Hits at 100: 0.9733414116934263
# Hits at 500: 0.9933353529233565
# Hits at 1000: 0.9966676764616783
# Validation MRR: 0.4868585047434113

# %%
ranks_test1 = []
j = 0 #keep track of all loops
for i, emb in enumerate(text_chem_cos_test1):
    for k in range(emb.shape[0]):
        cid_locs = np.argsort(emb[k,:])[::-1]
        ranks = np.argsort(cid_locs)

        test_avg_ranks[j,:] = test_avg_ranks[j,:] + ranks

        rank = ranks[j+offset_test] + 1
        ranks_test1.append(rank)

        j += 1
        if (j) % 1000 == 0: print((j), "test processed.")

ranks_test1 = np.array(ranks_test1)

print()
print("Test Mean rank:", np.mean(ranks_test1))
print("Hits at 1:", np.mean(ranks_test1 <= 1))
print("Hits at 10:", np.mean(ranks_test1 <= 10))
print("Hits at 100:", np.mean(ranks_test1 <= 100))
print("Hits at 500:", np.mean(ranks_test1 <= 500))
print("Hits at 1000:", np.mean(ranks_test1 <= 1000))

print("Test MRR:", np.mean(1/ranks_test1))
# Out:
# 1000 test processed.
# 2000 test processed.
# 3000 test processed.
#
# Test Mean rank: 26.039684943956377
# Hits at 1: 0.3374734928809452
# Hits at 10: 0.8288397455316571
# Hits at 100: 0.97364435019691
# Hits at 500: 0.9936382914268403
# Hits at 1000: 0.9963647379581945
# Test MRR: 0.4998553337137297

# %%
#For space 2:

ranks2 = []
j = 0 #keep track of all loops
for i, emb in enumerate(text_chem_cos2):
    for k in range(emb.shape[0]):
        cid_locs = np.argsort(emb[k,:])[::-1]
        ranks = np.argsort(cid_locs)

        tr_ranks_avg[j,:] = tr_ranks_avg[j,:] + ranks

        rank = ranks[j] + 1
        ranks2.append(rank)


        j += 1
        if (j) % 1000 == 0: print((j), "train processed.")

ranks2 = np.array(ranks2)

print()
print("Training Mean rank:", np.mean(ranks2))
print("Hits at 1:", np.mean(ranks2 <= 1))
print("Hits at 10:", np.mean(ranks2 <= 10))
print("Hits at 100:", np.mean(ranks2 <= 100))
print("Hits at 500:", np.mean(ranks2 <= 500))
print("Hits at 1000:", np.mean(ranks2 <= 1000))

print("Training MRR:", np.mean(1/ranks2))
# Out:
# 1000 train processed.
# 2000 train processed.
# 3000 train processed.
# 4000 train processed.
# 5000 train processed.
# 6000 train processed.
# 7000 train processed.
# 8000 train processed.
# 9000 train processed.
# 10000 train processed.
# 11000 train processed.
# 12000 train processed.
# 13000 train processed.
# 14000 train processed.
# 15000 train processed.
# 16000 train processed.
# 17000 train processed.
# 18000 train processed.
# 19000 train processed.
# 20000 train processed.
# 21000 train processed.
# 22000 train processed.
# 23000 train processed.
# 24000 train processed.
# 25000 train processed.
# 26000 train processed.
#
# Training Mean rank: 3.715427143289912
# Hits at 1: 0.43615571039079065
# Hits at 10: 0.9336186004241139
# Hits at 100: 0.9994319903059679
# Hits at 500: 1.0
# Hits at 1000: 1.0
# Training MRR: 0.6069887371158339

# %%
ranks_val2 = []
j = 0 #keep track of all loops
for i, emb in enumerate(text_chem_cos_val2):
    for k in range(emb.shape[0]):
        cid_locs = np.argsort(emb[k,:])[::-1]
        ranks = np.argsort(cid_locs)

        val_avg_ranks[j,:] = val_avg_ranks[j,:] + ranks

        rank = ranks[j+offset_val] + 1
        ranks_val2.append(rank)


        j += 1
        if (j) % 1000 == 0: print((j), "val processed.")


ranks_val2 = np.array(ranks_val2)

print()
print("Val Mean rank:", np.mean(ranks_val2))
print("Hits at 1:", np.mean(ranks_val2 <= 1))
print("Hits at 10:", np.mean(ranks_val2 <= 10))
print("Hits at 100:", np.mean(ranks_val2 <= 100))
print("Hits at 500:", np.mean(ranks_val2 <= 500))
print("Hits at 1000:", np.mean(ranks_val2 <= 1000))

print("Validation MRR:", np.mean(1/ranks_val2))
# Out:
# 1000 val processed.
# 2000 val processed.
# 3000 val processed.
#
# Val Mean rank: 29.148742805210542
# Hits at 1: 0.334747046349591
# Hits at 10: 0.8209633444410784
# Hits at 100: 0.9724325961829748
# Hits at 500: 0.9939412299303242
# Hits at 1000: 0.996970614965162
# Validation MRR: 0.4991055092653233

# %%
ranks_test2 = []
j = 0 #keep track of all loops
for i, emb in enumerate(text_chem_cos_test2):
    for k in range(emb.shape[0]):
        cid_locs = np.argsort(emb[k,:])[::-1]
        ranks = np.argsort(cid_locs)

        test_avg_ranks[j,:] = test_avg_ranks[j,:] + ranks

        rank = ranks[j+offset_test] + 1
        ranks_test2.append(rank)

        j += 1
        if (j) % 1000 == 0: print((j), "test processed.")

ranks_test2 = np.array(ranks_test2)

print()
print("Test Mean rank:", np.mean(ranks_test2))
print("Hits at 1:", np.mean(ranks_test2 <= 1))
print("Hits at 10:", np.mean(ranks_test2 <= 10))
print("Hits at 100:", np.mean(ranks_test2 <= 100))
print("Hits at 500:", np.mean(ranks_test2 <= 500))
print("Hits at 1000:", np.mean(ranks_test2 <= 1000))

print("Test MRR:", np.mean(1/ranks_test2))
# Out:
# 1000 test processed.
# 2000 test processed.
# 3000 test processed.
#
# Test Mean rank: 25.815813389881853
# Hits at 1: 0.34413813995758863
# Hits at 10: 0.8270221145107544
# Hits at 100: 0.97364435019691
# Hits at 500: 0.9924265374129052
# Hits at 1000: 0.9957588609512269
# Test MRR: 0.504086855686544

# %%
#For space 3:

ranks3 = []
j = 0 #keep track of all loops
for i, emb in enumerate(text_chem_cos3):
    for k in range(emb.shape[0]):
        cid_locs = np.argsort(emb[k,:])[::-1]
        ranks = np.argsort(cid_locs)

        tr_ranks_avg[j,:] = tr_ranks_avg[j,:] + ranks

        rank = ranks[j] + 1
        ranks3.append(rank)


        j += 1
        if (j) % 1000 == 0: print((j), "train processed.")

ranks3 = np.array(ranks3)

print()
print("Training Mean rank:", np.mean(ranks3))
print("Hits at 1:", np.mean(ranks3 <= 1))
print("Hits at 10:", np.mean(ranks3 <= 10))
print("Hits at 100:", np.mean(ranks3 <= 100))
print("Hits at 500:", np.mean(ranks3 <= 500))
print("Hits at 1000:", np.mean(ranks3 <= 1000))

print("Training MRR:", np.mean(1/ranks3))
# Out:
# 1000 train processed.
# 2000 train processed.
# 3000 train processed.
# 4000 train processed.
# 5000 train processed.
# 6000 train processed.
# 7000 train processed.
# 8000 train processed.
# 9000 train processed.
# 10000 train processed.
# 11000 train processed.
# 12000 train processed.
# 13000 train processed.
# 14000 train processed.
# 15000 train processed.
# 16000 train processed.
# 17000 train processed.
# 18000 train processed.
# 19000 train processed.
# 20000 train processed.
# 21000 train processed.
# 22000 train processed.
# 23000 train processed.
# 24000 train processed.
# 25000 train processed.
# 26000 train processed.
#
# Training Mean rank: 3.7252726446531352
# Hits at 1: 0.4282035746743411
# Hits at 10: 0.9344138139957588
# Hits at 100: 0.9995455922447744
# Hits at 500: 1.0
# Hits at 1000: 1.0
# Training MRR: 0.6001099259851892

# %%
ranks_val3 = []
j = 0 #keep track of all loops
for i, emb in enumerate(text_chem_cos_val3):
    for k in range(emb.shape[0]):
        cid_locs = np.argsort(emb[k,:])[::-1]
        ranks = np.argsort(cid_locs)

        val_avg_ranks[j,:] = val_avg_ranks[j,:] + ranks

        rank = ranks[j+offset_val] + 1
        ranks_val3.append(rank)


        j += 1
        if (j) % 1000 == 0: print((j), "val processed.")


ranks_val3 = np.array(ranks_val3)

print()
print("Val Mean rank:", np.mean(ranks_val3))
print("Hits at 1:", np.mean(ranks_val3 <= 1))
print("Hits at 10:", np.mean(ranks_val3 <= 10))
print("Hits at 100:", np.mean(ranks_val3 <= 100))
print("Hits at 500:", np.mean(ranks_val3 <= 500))
print("Hits at 1000:", np.mean(ranks_val3 <= 1000))

print("Validation MRR:", np.mean(1/ranks_val3))
# Out:
# 1000 val processed.
# 2000 val processed.
# 3000 val processed.
#
# Val Mean rank: 27.35049984853075
# Hits at 1: 0.32414419872765826
# Hits at 10: 0.8146016358679188
# Hits at 100: 0.9700090881551046
# Hits at 500: 0.9915177219024538
# Hits at 1000: 0.9960617994547107
# Validation MRR: 0.48746504602420726

# %%
tmp = cids_all[np.argsort(val_avg_ranks[1396,:])]
print(tmp)
print(np.where(tmp == '45359507')[0][0] + 1)
# Out:
# ['70698233' '50908215' '70678760' ... '364' '97328' '3301']
# 5796

# %%
ranks_test3 = []
j = 0 #keep track of all loops
for i, emb in enumerate(text_chem_cos_test3):
    for k in range(emb.shape[0]):
        cid_locs = np.argsort(emb[k,:])[::-1]
        ranks = np.argsort(cid_locs)

        test_avg_ranks[j,:] = test_avg_ranks[j,:] + ranks

        rank = ranks[j+offset_test] + 1
        ranks_test3.append(rank)

        j += 1
        if (j) % 1000 == 0: print((j), "test processed.")

ranks_test3 = np.array(ranks_test3)

print()
print("Test Mean rank:", np.mean(ranks_test3))
print("Hits at 1:", np.mean(ranks_test3 <= 1))
print("Hits at 10:", np.mean(ranks_test3 <= 10))
print("Hits at 100:", np.mean(ranks_test3 <= 100))
print("Hits at 500:", np.mean(ranks_test3 <= 500))
print("Hits at 1000:", np.mean(ranks_test3 <= 1000))

print("Test MRR:", np.mean(1/ranks_test3))
# Out:
# 1000 test processed.
# 2000 test processed.
# 3000 test processed.
#
# Test Mean rank: 25.154195698273252
# Hits at 1: 0.33838230839139655
# Hits at 10: 0.830354438049076
# Hits at 100: 0.9730384731899424
# Hits at 500: 0.9933353529233565
# Hits at 1000: 0.996970614965162
# Test MRR: 0.5008305760925637

# %%
#For space 4:

ranks4 = []
j = 0 #keep track of all loops
for i, emb in enumerate(text_chem_cos4):
    for k in range(emb.shape[0]):
        cid_locs = np.argsort(emb[k,:])[::-1]
        ranks = np.argsort(cid_locs)

        tr_ranks_avg[j,:] = tr_ranks_avg[j,:] + ranks

        rank = ranks[j] + 1
        ranks4.append(rank)


        j += 1
        if (j) % 1000 == 0: print((j), "train processed.")

ranks4 = np.array(ranks4)

print()
print("Training Mean rank:", np.mean(ranks4))
print("Hits at 1:", np.mean(ranks4 <= 1))
print("Hits at 10:", np.mean(ranks4 <= 10))
print("Hits at 100:", np.mean(ranks4 <= 100))
print("Hits at 500:", np.mean(ranks4 <= 500))
print("Hits at 1000:", np.mean(ranks4 <= 1000))

print("Training MRR:", np.mean(1/ranks4))
# Out:
# 1000 train processed.
# 2000 train processed.
# 3000 train processed.
# 4000 train processed.
# 5000 train processed.
# 6000 train processed.
# 7000 train processed.
# 8000 train processed.
# 9000 train processed.
# 10000 train processed.
# 11000 train processed.
# 12000 train processed.
# 13000 train processed.
# 14000 train processed.
# 15000 train processed.
# 16000 train processed.
# 17000 train processed.
# 18000 train processed.
# 19000 train processed.
# 20000 train processed.
# 21000 train processed.
# 22000 train processed.
# 23000 train processed.
# 24000 train processed.
# 25000 train processed.
# 26000 train processed.
#
# Training Mean rank: 3.5492275068161163
# Hits at 1: 0.44160860345349895
# Hits at 10: 0.9382005452893063
# Hits at 100: 1.0
# Hits at 500: 1.0
# Hits at 1000: 1.0
# Training MRR: 0.6111997206165773

# %%
ranks_val4 = []
j = 0 #keep track of all loops
for i, emb in enumerate(text_chem_cos_val4):
    for k in range(emb.shape[0]):
        cid_locs = np.argsort(emb[k,:])[::-1]
        ranks = np.argsort(cid_locs)

        val_avg_ranks[j,:] = val_avg_ranks[j,:] + ranks


        rank = ranks[j+offset_val] + 1
        ranks_val4.append(rank)


        j += 1
        if (j) % 1000 == 0: print((j), "val processed.")


ranks_val4 = np.array(ranks_val4)

print()
print("Val Mean rank:", np.mean(ranks_val4))
print("Hits at 1:", np.mean(ranks_val4 <= 1))
print("Hits at 10:", np.mean(ranks_val4 <= 10))
print("Hits at 100:", np.mean(ranks_val4 <= 100))
print("Hits at 500:", np.mean(ranks_val4 <= 500))
print("Hits at 1000:", np.mean(ranks_val4 <= 1000))

print("Validation MRR:", np.mean(1/ranks_val4))
# Out:
# 1000 val processed.
# 2000 val processed.
# 3000 val processed.
#
# Val Mean rank: 30.87943047561345
# Hits at 1: 0.3314147228112693
# Hits at 10: 0.8370190851257194
# Hits at 100: 0.9730384731899424
# Hits at 500: 0.99121478339897
# Hits at 1000: 0.9963647379581945
# Validation MRR: 0.49951891835195567

# %%
ranks_test4 = []
j = 0 #keep track of all loops
for i, emb in enumerate(text_chem_cos_test4):
    for k in range(emb.shape[0]):
        cid_locs = np.argsort(emb[k,:])[::-1]
        ranks = np.argsort(cid_locs)

        test_avg_ranks[j,:] = test_avg_ranks[j,:] + ranks

        rank = ranks[j+offset_test] + 1
        ranks_test4.append(rank)

        j += 1
        if (j) % 1000 == 0: print((j), "test processed.")

ranks_test4 = np.array(ranks_test4)

print()
print("Test Mean rank:", np.mean(ranks_test4))
print("Hits at 1:", np.mean(ranks_test4 <= 1))
print("Hits at 10:", np.mean(ranks_test4 <= 10))
print("Hits at 100:", np.mean(ranks_test4 <= 100))
print("Hits at 500:", np.mean(ranks_test4 <= 500))
print("Hits at 1000:", np.mean(ranks_test4 <= 1000))

print("Test MRR:", np.mean(1/ranks_test4))
# Out:
# 1000 test processed.
# 2000 test processed.
# 3000 test processed.
#
# Test Mean rank: 27.783398970009088
# Hits at 1: 0.33383823083913966
# Hits at 10: 0.8409572856710088
# Hits at 100: 0.9760678582247804
# Hits at 500: 0.9924265374129052
# Hits at 1000: 0.9954559224477431
# Test MRR: 0.5027490140721781

# %%
#For space 5:

ranks5 = []
j = 0 #keep track of all loops
for i, emb in enumerate(text_chem_cos5):
    for k in range(emb.shape[0]):
        cid_locs = np.argsort(emb[k,:])[::-1]
        ranks = np.argsort(cid_locs)

        tr_ranks_avg[j,:] = tr_ranks_avg[j,:] + ranks

        rank = ranks[j] + 1
        ranks5.append(rank)


        j += 1
        if (j) % 1000 == 0: print((j), "train processed.")

ranks5 = np.array(ranks5)

print()
print("Training Mean rank:", np.mean(ranks5))
print("Hits at 1:", np.mean(ranks5 <= 1))
print("Hits at 10:", np.mean(ranks5 <= 10))
print("Hits at 100:", np.mean(ranks5 <= 100))
print("Hits at 500:", np.mean(ranks5 <= 500))
print("Hits at 1000:", np.mean(ranks5 <= 1000))

print("Training MRR:", np.mean(1/ranks5))
# Out:
# 1000 train processed.
# 2000 train processed.
# 3000 train processed.
# 4000 train processed.
# 5000 train processed.
# 6000 train processed.
# 7000 train processed.
# 8000 train processed.
# 9000 train processed.
# 10000 train processed.
# 11000 train processed.
# 12000 train processed.
# 13000 train processed.
# 14000 train processed.
# 15000 train processed.
# 16000 train processed.
# 17000 train processed.
# 18000 train processed.
# 19000 train processed.
# 20000 train processed.
# 21000 train processed.
# 22000 train processed.
# 23000 train processed.
# 24000 train processed.
# 25000 train processed.
# 26000 train processed.
#
# Training Mean rank: 3.6999394122993032
# Hits at 1: 0.4267267494698576
# Hits at 10: 0.9336564677370494
# Hits at 100: 0.9999621326870646
# Hits at 500: 1.0
# Hits at 1000: 1.0
# Training MRR: 0.5997151843584806

# %%
ranks_val5 = []
j = 0 #keep track of all loops
for i, emb in enumerate(text_chem_cos_val5):
    for k in range(emb.shape[0]):
        cid_locs = np.argsort(emb[k,:])[::-1]
        ranks = np.argsort(cid_locs)

        val_avg_ranks[j,:] = val_avg_ranks[j,:] + ranks

        rank = ranks[j+offset_val] + 1
        ranks_val5.append(rank)


        j += 1
        if (j) % 1000 == 0: print((j), "val processed.")


ranks_val5 = np.array(ranks_val5)

print()
print("Val Mean rank:", np.mean(ranks_val5))
print("Hits at 1:", np.mean(ranks_val5 <= 1))
print("Hits at 10:", np.mean(ranks_val5 <= 10))
print("Hits at 100:", np.mean(ranks_val5 <= 100))
print("Hits at 500:", np.mean(ranks_val5 <= 500))
print("Hits at 1000:", np.mean(ranks_val5 <= 1000))

print("Validation MRR:", np.mean(1/ranks_val5))
# Out:
# 1000 val processed.
# 2000 val processed.
# 3000 val processed.
#
# Val Mean rank: 29.025143895789157
# Hits at 1: 0.32838533777643136
# Hits at 10: 0.8267191760072705
# Hits at 100: 0.9697061496516207
# Hits at 500: 0.9906089063920024
# Hits at 1000: 0.9954559224477431
# Validation MRR: 0.4913466068478193

# %%
ranks_test5 = []
j = 0 #keep track of all loops
for i, emb in enumerate(text_chem_cos_test5):
    for k in range(emb.shape[0]):
        cid_locs = np.argsort(emb[k,:])[::-1]
        ranks = np.argsort(cid_locs)

        test_avg_ranks[j,:] = test_avg_ranks[j,:] + ranks

        rank = ranks[j+offset_test] + 1
        ranks_test5.append(rank)

        j += 1
        if (j) % 1000 == 0: print((j), "test processed.")

ranks_test5 = np.array(ranks_test5)

print()
print("Test Mean rank:", np.mean(ranks_test5))
print("Hits at 1:", np.mean(ranks_test5 <= 1))
print("Hits at 10:", np.mean(ranks_test5 <= 10))
print("Hits at 100:", np.mean(ranks_test5 <= 100))
print("Hits at 500:", np.mean(ranks_test5 <= 500))
print("Hits at 1000:", np.mean(ranks_test5 <= 1000))

print("Test MRR:", np.mean(1/ranks_test5))
# Out:
# 1000 test processed.
# 2000 test processed.
# 3000 test processed.
#
# Test Mean rank: 25.854589518327778
# Hits at 1: 0.34232050893668586
# Hits at 10: 0.8282338685246895
# Hits at 100: 0.9748561042108452
# Hits at 500: 0.9924265374129052
# Hits at 1000: 0.9945471069372918
# Test MRR: 0.5034708663289943

# %%
#For space 6:

ranks6 = []
j = 0 #keep track of all loops
for i, emb in enumerate(text_chem_cos6):
    for k in range(emb.shape[0]):
        cid_locs = np.argsort(emb[k,:])[::-1]
        ranks = np.argsort(cid_locs)

        tr_ranks_avg[j,:] = tr_ranks_avg[j,:] + ranks

        rank = ranks[j] + 1
        ranks6.append(rank)


        j += 1
        if (j) % 1000 == 0: print((j), "train processed.")

ranks6 = np.array(ranks6)

print()
print("Training Mean rank:", np.mean(ranks6))
print("Hits at 1:", np.mean(ranks6 <= 1))
print("Hits at 10:", np.mean(ranks6 <= 10))
print("Hits at 100:", np.mean(ranks6 <= 100))
print("Hits at 500:", np.mean(ranks6 <= 500))
print("Hits at 1000:", np.mean(ranks6 <= 1000))

print("Training MRR:", np.mean(1/ranks6))
# Out:
# 1000 train processed.
# 2000 train processed.
# 3000 train processed.
# 4000 train processed.
# 5000 train processed.
# 6000 train processed.
# 7000 train processed.
# 8000 train processed.
# 9000 train processed.
# 10000 train processed.
# 11000 train processed.
# 12000 train processed.
# 13000 train processed.
# 14000 train processed.
# 15000 train processed.
# 16000 train processed.
# 17000 train processed.
# 18000 train processed.
# 19000 train processed.
# 20000 train processed.
# 21000 train processed.
# 22000 train processed.
# 23000 train processed.
# 24000 train processed.
# 25000 train processed.
# 26000 train processed.
#
# Training Mean rank: 3.6095501363223264
# Hits at 1: 0.4347546198121781
# Hits at 10: 0.9359663738261133
# Hits at 100: 0.999924265374129
# Hits at 500: 1.0
# Hits at 1000: 1.0
# Training MRR: 0.606411704411532

# %%
ranks_val6 = []
j = 0 #keep track of all loops
for i, emb in enumerate(text_chem_cos_val6):
    for k in range(emb.shape[0]):
        cid_locs = np.argsort(emb[k,:])[::-1]
        ranks = np.argsort(cid_locs)

        val_avg_ranks[j,:] = val_avg_ranks[j,:] + ranks

        rank = ranks[j+offset_val] + 1
        ranks_val6.append(rank)


        j += 1
        if (j) % 1000 == 0: print((j), "val processed.")


ranks_val6 = np.array(ranks_val6)

print()
print("Val Mean rank:", np.mean(ranks_val6))
print("Hits at 1:", np.mean(ranks_val6 <= 1))
print("Hits at 10:", np.mean(ranks_val6 <= 10))
print("Hits at 100:", np.mean(ranks_val6 <= 100))
print("Hits at 500:", np.mean(ranks_val6 <= 500))
print("Hits at 1000:", np.mean(ranks_val6 <= 1000))

print("Validation MRR:", np.mean(1/ranks_val6))
# Out:
# 1000 val processed.
# 2000 val processed.
# 3000 val processed.
#
# Val Mean rank: 28.72432596182975
# Hits at 1: 0.3398970009088155
# Hits at 10: 0.8279309300212057
# Hits at 100: 0.9697061496516207
# Hits at 500: 0.9921235989094214
# Hits at 1000: 0.9960617994547107
# Validation MRR: 0.503280663610302

# %%
ranks_test6 = []
j = 0 #keep track of all loops
for i, emb in enumerate(text_chem_cos_test6):
    for k in range(emb.shape[0]):
        cid_locs = np.argsort(emb[k,:])[::-1]
        ranks = np.argsort(cid_locs)

        test_avg_ranks[j,:] = test_avg_ranks[j,:] + ranks

        rank = ranks[j+offset_test] + 1
        ranks_test6.append(rank)

        j += 1
        if (j) % 1000 == 0: print((j), "test processed.")

ranks_test6 = np.array(ranks_test6)

print()
print("Test Mean rank:", np.mean(ranks_test6))
print("Hits at 1:", np.mean(ranks_test6 <= 1))
print("Hits at 10:", np.mean(ranks_test6 <= 10))
print("Hits at 100:", np.mean(ranks_test6 <= 100))
print("Hits at 500:", np.mean(ranks_test6 <= 500))
print("Hits at 1000:", np.mean(ranks_test6 <= 1000))

print("Test MRR:", np.mean(1/ranks_test6))
# Out:
# 1000 test processed.
# 2000 test processed.
# 3000 test processed.
#
# Test Mean rank: 21.968494395637684
# Hits at 1: 0.35383217206907
# Hits at 10: 0.8448954862162981
# Hits at 100: 0.9742502272038777
# Hits at 500: 0.9945471069372918
# Hits at 1000: 0.9972735534686459
# Test MRR: 0.514169838664429

# %%
# CHANGE START
#For space 7 (using training data)
ranks7 = []
j = 0 #keep track of all loops
for i, emb in enumerate(text_chem_cos7):
    for k in range(emb.shape[0]):
        cid_locs = np.argsort(emb[k,:])[::-1]
        ranks = np.argsort(cid_locs)

        tr_ranks_avg[j,:] = tr_ranks_avg[j,:] + ranks

        rank = ranks[j] + 1
        ranks7.append(rank)


        j += 1
        if (j) % 1000 == 0: print((j), "train processed.")

ranks7 = np.array(ranks7)

print()
print("Training Mean rank:", np.mean(ranks7))
print("Hits at 1:", np.mean(ranks7 <= 1))
print("Hits at 10:", np.mean(ranks7 <= 10))
print("Hits at 100:", np.mean(ranks7 <= 100))
print("Hits at 500:", np.mean(ranks7 <= 500))
print("Hits at 1000:", np.mean(ranks7 <= 1000))

print("Training MRR:", np.mean(1/ranks7))

# CHANGE END
# Out:
# 1000 train processed.
# 2000 train processed.
# 3000 train processed.
# 4000 train processed.
# 5000 train processed.
# 6000 train processed.
# 7000 train processed.
# 8000 train processed.
# 9000 train processed.
# 10000 train processed.
# 11000 train processed.
# 12000 train processed.
# 13000 train processed.
# 14000 train processed.
# 15000 train processed.
# 16000 train processed.
# 17000 train processed.
# 18000 train processed.
# 19000 train processed.
# 20000 train processed.
# 21000 train processed.
# 22000 train processed.
# 23000 train processed.
# 24000 train processed.
# 25000 train processed.
# 26000 train processed.
#
# Training Mean rank: 3.7364435019691005
# Hits at 1: 0.4250227203877613
# Hits at 10: 0.9311950923962435
# Hits at 100: 0.9998863980611936
# Hits at 500: 1.0
# Hits at 1000: 1.0
# Training MRR: 0.5971187137536587

# %%
# CHANGE START
#For space 7 (using validation data)
ranks_val7 = []
j = 0 #keep track of all loops
for i, emb in enumerate(text_chem_cos_val7):
    for k in range(emb.shape[0]):
        cid_locs = np.argsort(emb[k,:])[::-1]
        ranks = np.argsort(cid_locs)

        val_avg_ranks[j,:] = val_avg_ranks[j,:] + ranks

        rank = ranks[j+offset_val] + 1
        ranks_val7.append(rank)


        j += 1
        if (j) % 1000 == 0: print((j), "val processed.")


ranks_val7 = np.array(ranks_val7)

print()
print("Val Mean rank:", np.mean(ranks_val7))
print("Hits at 1:", np.mean(ranks_val7 <= 1))
print("Hits at 10:", np.mean(ranks_val7 <= 10))
print("Hits at 100:", np.mean(ranks_val7 <= 100))
print("Hits at 500:", np.mean(ranks_val7 <= 500))
print("Hits at 1000:", np.mean(ranks_val7 <= 1000))

print("Validation MRR:", np.mean(1/ranks_val7))
# CHANGE END
# Out:
# 1000 val processed.
# 2000 val processed.
# 3000 val processed.
#
# Val Mean rank: 32.90487730990609
# Hits at 1: 0.3262647682520448
# Hits at 10: 0.810057558315662
# Hits at 100: 0.9684943956376856
# Hits at 500: 0.99121478339897
# Hits at 1000: 0.9948500454407755
# Validation MRR: 0.4859228792865391

# %%
# CHANGE START
#For space 7 (using test data)
ranks_test7 = []
j = 0 #keep track of all loops
for i, emb in enumerate(text_chem_cos_test7):
    for k in range(emb.shape[0]):
        cid_locs = np.argsort(emb[k,:])[::-1]
        ranks = np.argsort(cid_locs)

        test_avg_ranks[j,:] = test_avg_ranks[j,:] + ranks

        rank = ranks[j+offset_test] + 1
        ranks_test7.append(rank)

        j += 1
        if (j) % 1000 == 0: print((j), "test processed.")

ranks_test7 = np.array(ranks_test7)

print()
print("Test Mean rank:", np.mean(ranks_test7))
print("Hits at 1:", np.mean(ranks_test7 <= 1))
print("Hits at 10:", np.mean(ranks_test7 <= 10))
print("Hits at 100:", np.mean(ranks_test7 <= 100))
print("Hits at 500:", np.mean(ranks_test7 <= 500))
print("Hits at 1000:", np.mean(ranks_test7 <= 1000))

print("Test MRR:", np.mean(1/ranks_test7))
# CHANGE END
# Out:
# 1000 test processed.
# 2000 test processed.
# 3000 test processed.
#
# Test Mean rank: 26.340805816419266
# Hits at 1: 0.337776431384429
# Hits at 10: 0.8185398364132082
# Hits at 100: 0.9745531657073614
# Hits at 500: 0.9930324144198728
# Hits at 1000: 0.9963647379581945
# Test MRR: 0.4964937560063823

# %%
# CHANGE START
#For space 8 (using training data)
ranks8 = []
j = 0 #keep track of all loops
for i, emb in enumerate(text_chem_cos8):
    for k in range(emb.shape[0]):
        cid_locs = np.argsort(emb[k,:])[::-1]
        ranks = np.argsort(cid_locs)

        tr_ranks_avg[j,:] = tr_ranks_avg[j,:] + ranks

        rank = ranks[j] + 1
        ranks8.append(rank)


        j += 1
        if (j) % 1000 == 0: print((j), "train processed.")

ranks8 = np.array(ranks8)

print()
print("Training Mean rank:", np.mean(ranks8))
print("Hits at 1:", np.mean(ranks8 <= 1))
print("Hits at 10:", np.mean(ranks8 <= 10))
print("Hits at 100:", np.mean(ranks8 <= 100))
print("Hits at 500:", np.mean(ranks8 <= 500))
print("Hits at 1000:", np.mean(ranks8 <= 1000))

print("Training MRR:", np.mean(1/ranks8))

# CHANGE END
# Out:
# 1000 train processed.
# 2000 train processed.
# 3000 train processed.
# 4000 train processed.
# 5000 train processed.
# 6000 train processed.
# 7000 train processed.
# 8000 train processed.
# 9000 train processed.
# 10000 train processed.
# 11000 train processed.
# 12000 train processed.
# 13000 train processed.
# 14000 train processed.
# 15000 train processed.
# 16000 train processed.
# 17000 train processed.
# 18000 train processed.
# 19000 train processed.
# 20000 train processed.
# 21000 train processed.
# 22000 train processed.
# 23000 train processed.
# 24000 train processed.
# 25000 train processed.
# 26000 train processed.
#
# Training Mean rank: 3.596334444107846
# Hits at 1: 0.4384656164798546
# Hits at 10: 0.9377461375340805
# Hits at 100: 0.9999621326870646
# Hits at 500: 1.0
# Hits at 1000: 1.0
# Training MRR: 0.6086929781573421

# %%
# CHANGE START
#For space 8 (using validation data)
ranks_val8 = []
j = 0 #keep track of all loops
for i, emb in enumerate(text_chem_cos_val8):
    for k in range(emb.shape[0]):
        cid_locs = np.argsort(emb[k,:])[::-1]
        ranks = np.argsort(cid_locs)

        val_avg_ranks[j,:] = val_avg_ranks[j,:] + ranks

        rank = ranks[j+offset_val] + 1
        ranks_val8.append(rank)


        j += 1
        if (j) % 1000 == 0: print((j), "val processed.")


ranks_val8 = np.array(ranks_val8)

print()
print("Val Mean rank:", np.mean(ranks_val8))
print("Hits at 1:", np.mean(ranks_val8 <= 1))
print("Hits at 10:", np.mean(ranks_val8 <= 10))
print("Hits at 100:", np.mean(ranks_val8 <= 100))
print("Hits at 500:", np.mean(ranks_val8 <= 500))
print("Hits at 1000:", np.mean(ranks_val8 <= 1000))

print("Validation MRR:", np.mean(1/ranks_val8))
# CHANGE END
# Out:
# 1000 val processed.
# 2000 val processed.
# 3000 val processed.
#
# Val Mean rank: 30.926991820660405
# Hits at 1: 0.3417146319297183
# Hits at 10: 0.8291426840351409
# Hits at 100: 0.9706149651620721
# Hits at 500: 0.9906089063920024
# Hits at 1000: 0.9960617994547107
# Validation MRR: 0.5034985999968774

# %%
# CHANGE START
#For space 8 (using test data)
ranks_test8 = []
j = 0 #keep track of all loops
for i, emb in enumerate(text_chem_cos_test8):
    for k in range(emb.shape[0]):
        cid_locs = np.argsort(emb[k,:])[::-1]
        ranks = np.argsort(cid_locs)

        test_avg_ranks[j,:] = test_avg_ranks[j,:] + ranks

        rank = ranks[j+offset_test] + 1
        ranks_test8.append(rank)

        j += 1
        if (j) % 1000 == 0: print((j), "test processed.")

ranks_test8 = np.array(ranks_test8)

print()
print("Test Mean rank:", np.mean(ranks_test8))
print("Hits at 1:", np.mean(ranks_test8 <= 1))
print("Hits at 10:", np.mean(ranks_test8 <= 10))
print("Hits at 100:", np.mean(ranks_test8 <= 100))
print("Hits at 500:", np.mean(ranks_test8 <= 500))
print("Hits at 1000:", np.mean(ranks_test8 <= 1000))

print("Test MRR:", np.mean(1/ranks_test8))
# CHANGE END
# Out:
# 1000 test processed.
# 2000 test processed.
# 3000 test processed.
#
# Test Mean rank: 22.768857921841867
# Hits at 1: 0.334747046349591
# Hits at 10: 0.8324750075734626
# Hits at 100: 0.9784913662526508
# Hits at 500: 0.9948500454407755
# Hits at 1000: 0.9981823689790973
# Test MRR: 0.5012808306175419

# %% [markdown]
# #Rerank from sum

# %%
sorted = np.argsort(tr_ranks_avg)
new_tr_ranks = np.diag(np.argsort(sorted)) + 1

print(np.mean(new_tr_ranks))
print("%1:", np.mean(new_tr_ranks <= 1))
print("%10:", np.mean(new_tr_ranks <= 10))
print("%100:", np.mean(new_tr_ranks <= 100))

print("Trainng MRR:", np.mean(1/np.array(new_tr_ranks)))
# Out:
# 2.532755225689185
# %1: 0.5624431990305968
# %10: 0.9718645864889427
# %100: 1.0
# Trainng MRR: 0.7125535926418244

# %%
sorted = np.argsort(val_avg_ranks)
val_final_ranks = np.argsort(sorted) + 1
new_val_ranks = np.diag(val_final_ranks[:,offset_val:offset_test])

print(np.mean(new_val_ranks))
print("%1:", np.mean(new_val_ranks <= 1))
print("%10:", np.mean(new_val_ranks <= 10))
print("%100:", np.mean(new_val_ranks <= 100))

print("Validation MRR:", np.mean(1/np.array(new_val_ranks)))
# Out:
# 20.578915480157526
# %1: 0.42108451984247197
# %10: 0.8912450772493183
# %100: 0.9794001817631021
# Validation MRR: 0.5832640411758

# %%
sorted = np.argsort(test_avg_ranks)
test_final_ranks = np.argsort(sorted) + 1
new_test_ranks = np.diag(test_final_ranks[:,offset_test:])

print(np.mean(new_test_ranks))
print("%1:", np.mean(new_test_ranks <= 1))
print("%10:", np.mean(new_test_ranks <= 10))
print("%100:", np.mean(new_test_ranks <= 100))

print("Test MRR:", np.mean(1/new_test_ranks))
# Out:
# 15.76279915177219
# %1: 0.445925477128143
# %10: 0.8873068767040291
# %100: 0.9860648288397456
# Test MRR: 0.5994412861701751

# %%
# Record notebook end time and print elapsed time
end_time = time.time()
elapsed_time = end_time - start_time
print(f"Elapsed time: {elapsed_time:.2f} seconds")
# Out:
# Elapsed time: 1918.55 seconds
